# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()
import nltk
import os
import pandas as pd
from ast import literal_eval
import random
import tqdm
import re
import numpy as np

# %%
# Entities to extract 
# 1. Name of the candidate ( top line )
# 2. City (use external data to tag)
# 3. Phone no (use re)
# 4. E-mail addresses (use re)
# 5. Companies worked (use external data or spacy to extract)
# 6. Colleges/schools ( some re or pos based approach)
# 7. Experience ( worked _ years.. re)
# 8. Skills ( Bag of Skills )

# %%
files = os.listdir('./Resumes')

# %%
def clean_text(text):
    text = text.strip()
    text = re.sub(r'\t+',' ',text)
    text = re.sub(r'\n+','\n',text)
    return text.lower()

# %%
import tika
tika.initVM()
from tika import parser
def read_file(file):
    parsed = parser.from_file('./Resumes/'+file)
    #print(parsed["metadata"])
    #print(parsed["content"])
    return clean_text(parsed['content'])

# %%
resume_entities = pd.read_csv('resume_entities1.csv')
resume_entities.head()
# Out:
#                                file  \
# 0                    Venkat_BA.docx
# 1                     Shashank.docx
# 2  Anudeep N_Sr Java Developer.docx
# 3                 ram nandyala.docx
# 4                Neha Mugghala.docx
#
#                                               skills phone Organisations  \
# 0  [' microsoft office (excel word', ' powerpoint...  None          None
# 1                                                 []  None          None
# 2  ['\xa0html', ' css', ' xml', ' soap', ' hibern...  None          None
# 3  [' aws', ' swagger', ' node-js', ' angular2', ...  None          None
# 4  ['  java', ' spring', ' drools', ' oracle', ' ...  None          None
#
#   Institutes email   experience  \
# 0       None  None     9+ years
# 1       None  None  seven years
# 2       None  None     8+ years
# 3       None  None     8+ years
# 4       None  None     8+ years
#
#                                          person name  city  skills_len  \
# 0                                           Venkat N  None          50
# 1  2                                             ...  None           0
# 2                                            Anudeep  None          93
# 3                              RAMA KARTHIK NANDYALA  None         157
# 4                                             Sourya  None         146
#
#    orgs_len                                      skill_matches  \
# 0         0  {'agile': [(3890, 3895), (8719, 8724)], 'busin...
# 1         0  {'testing': [(3645, 3652), (4663, 4670), (4684...
# 2         0  {'java': [(5179, 5183)], 'spring': [(13276, 13...
# 3         0  {'java': [(21403, 21407), (22667, 22671), (233...
# 4         0  {'java': [(89, 93)], 'spring': [(9683, 9689), ...
#
#                                          org_matches  \
# 0  {'sprint': [(8909, 8915)], 'capital one': [(96...
# 1                         {'sprint': [(6704, 6710)]}
# 2  {'IBM': [(2912, 2915), (5319, 5322), (5950, 59...
# 3  {'Fifth Third Bank': [(13514, 13530)], 'IBM': ...
# 4  {'IBM': [(1164, 1167), (3751, 3754), (4390, 43...
#
#                                             entities
# 0  [(933, 938, 'skill'), (3890, 3895, 'skill'), (...
# 1  [(3645, 3652, 'skill'), (4663, 4670, 'skill'),...
# 2  [(60, 64, 'skill'), (330, 334, 'skill'), (783,...
# 3  [(615, 619, 'skill'), (675, 679, 'skill'), (50...
# 4  [(65, 69, 'skill'), (89, 93, 'skill'), (497, 5...

# %%
# words followed by 'client:'
def extract_organisation(text):
    lines = text.split('\n')
    orgs = list()
    for line in lines:
        if line.find('client:')>-1:
            if len(line.split(':'))>1:
                ent = line.split(':')[1].split(',')[0].strip()
                if ent != '':
                    org = nltk.tokenize.sent_tokenize(ent)[0]
                    #print(org)
                    orgs.append(org)
    #print(orgs)
    return orgs

# %%
organisations = list()
for ix in tqdm.tqdm(resume_entities.index):
    doc = resume_entities.loc[ix]
    text = read_file(doc['file'])
    organisations.append(extract_organisation(text))
resume_entities['Organisations'] = organisations
# Out:
# 100%|██████████| 228/228 [00:53<00:00,  4.25it/s]

# %%
#words followed by environment:
def extract_skills(text):
    skills = list()
    for line in text.split('\n'):
        line = line.lower()
        if line.find('environment:')>-1:
            skills.extend(line.replace('environment:','').split(','))
    return skills

# %%
skills = list()
for ix in tqdm.tqdm(resume_entities.index):
    doc = resume_entities.loc[ix]
    text = read_file(doc['file'])
    skills.append(extract_skills(text))
resume_entities['skills'] = skills
# Out:
# 100%|██████████| 228/228 [00:49<00:00,  4.63it/s]

# %%
all_skills = list()
#x = [all_skills.extend(literal_eval(_)) for _ in resume_entities['skills']]
x = [all_skills.extend(_) for _ in resume_entities['skills']]

# %%
all_skills
# Out:
# [' microsoft office (excel word',
#  ' powerpoint',
#  ' project)',
#  ' sharepoint',
#  ' ms-visio 2010',
#  ' oracle hcm',
#  ' kronos',
#  ' hp alm.',
#  ' microsoft office (excel',
#  ' word',
#  ' powerpoint)',
#  '  peoplesoft 9.2',
#  ' qc alm. ',
#  ' microsoft office (excel',
#  ' word',
#  ' powerpoint)',
#  ' scrum wise',
#  ' jira',
#  ' sharepoint',
#  ' jenkins ',
#  'kronos',
#  '  oracle hcm.',
#  ' microsoft office (excel word',
#  ' powerpoint',
#  ' project)',
#  ' innotas',
#  ' rally',
#  ' sharepoint',
#  ' ms-visio 2010.',
#  ' microsoft office (excel word',
#  ' powerpoint)',
#  ' ms visio 2010',
#  ' sharepoint 2010.',
#  ' sap ecc 6.0 ',
#  ' sd ',
#  ' eh&s',
#  ' fico ',
#  ' alm',
#  ' scrum wise',
#  ' microsoft office (excel word',
#  ' powerpoint',
#  ' project)',
#  ' rational requisite pro',
#  ' ms visio.',
#  ' sap 4.7 and ecc 6.0',
#  ' isu',
#  ' sd ',
#  ' fico ',
#  ' alm',
#  ' scrum wise',
#  '\xa0html',
#  ' css',
#  ' xml',
#  ' soap',
#  ' hibernate',
#  ' java',
#  'j2ee',
#  'java script',
#  'mysql db',
#  ' spring boot',
#  ' pl/sql',
#  ' log4j',
#  ' jquery',
#  ' angular js',
#  ' eclipse',
#  ' ibm web sphere application server.',
#  '\xa0java',
#  ' jsp',
#  ' spring (mvc and core)',
#  ' json',
#  ' servlets',
#  ' webservices(restful)',
#  ' web logic application server',
#  ' websphere application server 6.0/6.1/7.0',
#  ' websphere portal server 6.0/6.1',
#  ' websphere commerce server 6.0',
#  ' apache 2.0.47',
#  ' ihs 6.0/6.1',
#  'html5',
#  ' css3',
#  ' javascript',
#  ' jquery',
#  ' dom',
#  ' dml',
#  ' dhtml',
#  ' ext js',
#  ' angular.js',
#  ' node.js',
#  ' backbone.js',
#  ' require.js',
#  ' adobe flash',
#  ' photoshop',
#  ' dreamweaver',
#  ' xml',
#  ' apache',
#  ' soap',
#  ' internet explorer',
#  ' firefox',
#  ' chrome',
#  ' oracle',
#  ' windows',
#  ' c',
#  ' c++',
#  ' agile methodology.',
#  ' core java',
#  ' jdk 1.5',
#  ' j2ee 5',
#  ' html',
#  ' css 2.1',
#  ' jsp 2.1',
#  ' jsf 1.2',
#  ' jndi',
#  ' ajax',
#  ' swing',
#  ' spring 2.5',
#  ' hibernate 3.0',
#  ' jms 1.1',
#  ' soap ui',
#  ' wsdl',
#  ' uml',
#  ' xml',
#  ' xslt',
#  ' windows xp',
#  ' ant',
#  ' unix',
#  ' log4j',
#  ' mvc design pattern',
#  ' dao',
#  ' eclipse ide.',
#  ' java',
#  ' j2ee',
#  ' spring framework',
#  ' html',
#  ' javascript',
#  ' hibernate',
#  ' eclipse ide',
#  ' star team',
#  ' axis',
#  ' soap',
#  ' junit',
#  ' rad',
#  ' eclipse',
#  ' netbeans.',
#  ' aws',
#  ' swagger',
#  ' node-js',
#  ' angular2',
#  ' type script',
#  ' web pack',
#  ' ecma6',
#  ' karma and jasmine',
#  ' spring boot',
#  ' spring cloud like ribbon',
#  ' hystix',
#  ' netflix zul',
#  ' angular2 injection annotations',
#  ' angular2 shadow dom',
#  ' micro services architecture',
#  ' docker',
#  ' cassandra db',
#  ' oauth',
#  ' site minder',
#  ' java8 ',
#  ' java/j2ee 1.6',
#  ' jsp',
#  ' spring boot',
#  ' angularjs',
#  ' node-js',
#  ' css3 and javascript',
#  ' xml',
#  ' eclipse ide',
#  ' maven',
#  ' jenkins',
#  ' react js',
#  ' redux',
#  ' spring boot',
#  ' node js',
#  ' express js',
#  ' npm',
#  ' web pack',
#  ' docker',
#  ' kubernetes',
#  ' cloud foundry',
#  ' jenkins',
#  ' ecms 6',
#  ' jsx-react',
#  ' axios',
#  ' react life cycle',
#  ' mongo db',
#  ' mongoose connection',
#  ' node js service',
#  ' open id connection',
#  ' oauth',
#  ' html',
#  ' css3.',
#  ' java',
#  ' j2ee',
#  ' core java',
#  ' spring boot',
#  ' spring frame work',
#  ' jsf',
#  ' ejb',
#  ' jms',
#  ' ajax',
#  ' javascript',
#  ' spring mvc',
#  ' spring batch',
#  ' spring security',
#  ' spring ioc',
#  ' apache cxf',
#  ' rest service',
#  ' jax rs',
#  ' brools',
#  ' angular js',
#  ' angular controllers',
#  ' angular customs directions',
#  ' digestive cycle',
#  ' karma and jasmine',
#  ' multi threading',
#  ' aws',
#  ' jquery',
#  ' html5',
#  ' css3',
#  ' ajax',
#  ' oracle',
#  ' rabbit mq.',
#  ' java/j2ee',
#  ' sql',
#  ' pl/sql',
#  ' xml',
#  ' maven',
#  ' junit',
#  ' spring mvc',
#  ' spring ioc',
#  ' spring security',
#  ' jsp',
#  ' spring batch',
#  ' java script',
#  ' jquery',
#  ' backbone js',
#  ' handle bar js',
#  ' core java',
#  ' hibernates',
#  ' unix script',
#  ' shell scripts',
#  ' jax ws',
#  ' soap services',
#  ' jax ws security',
#  ' wsdl-2',
#  'html',
#  'css',
#  'ajax',
#  ' ibm mq',
#  ' ibm websphere. ',
#  '  j2ee',
#  ' jsf',
#  ' xhtml',
#  ' bootstrap',
#  ' json',
#  ' javascript',
#  ' oracle',
#  ' spring framework',
#  ' spring ioc',
#  ' java multithreading',
#  ' prime faces',
#  ' spring batch',
#  ' jax ws',
#  ' soap services',
#  ' stored procedures in sql server',
#  ' drools',
#  ' spring aop',
#  ' ibatis',
#  ' hibernate',
#  ' mysql ',
#  ' pl/sql',
#  ' xml',
#  ' wsdl',
#  ' soap',
#  ' soap ui',
#  ' ibm websphere junit',
#  ' web sphere application server',
#  ' tomcat.\xa0',
#  ' java',
#  ' j2ee',
#  ' jsp',
#  ' jstl',
#  ' swing',
#  ' jsp',
#  ' html',
#  ' css',
#  ' servlets',
#  ' struts',
#  ' ejb',
#  ' web logic',
#  ' xml',
#  ' javascript',
#  ' java core like multithreading',
#  ' collections',
#  ' interface and abstract classes',
#  ' strings.',
#  '  java',
#  ' spring',
#  ' drools',
#  ' oracle',
#  ' rest',
#  ' xml',
#  ' vxml',
#  ' eclipse',
#  ' atom',
#  ' webstorm',
#  ' maven',
#  ' ms visio',
#  ' rally',
#  ' jazz',
#  ' git (egit',
#  ' sourcetree and tortoisegit)',
#  ' agile',
#  ' scrum',
#  ' camunda bpm',
#  ' jquery',
#  ' log4j',
#  ' html',
#  ' nodejs',
#  ' json',
#  ' cassandra',
#  ' kafka',
#  ' vuejs',
#  ' pugjs',
#  '  junit',
#  ' mocha',
#  ' gulp',
#  ' chai',
#  ' apache http server',
#  ' jboss server.',
#  ' java1.6',
#  '\xa0j2ee',
#  ' servlets 2.4',
#  ' ejb 2.0',
#  ' jdbc 2.0',
#  ' jaxb',
#  ' spring-ioc/di',
#  ' aop',
#  ' mvc',
#  ' boot',
#  ' jsf',
#  ' python',
#  ' rest api',
#  ' dao',
#  ' html',
#  '\xa0java script',
#  ' xml',
#  ' css',
#  ' ajax',
#  ' angularjs',
#  ' web sphere application server8.0',
#  ' ldap',
#  ' oracle 10g',
#  ' log4j',
#  ' eclipse 3.1',
#  ' cvs',
#  ' dojo',
#  ' ant 1.5',
#  ' soa',
#  ' mule esb',
#  ' soap',
#  ' db2',
#  ' pl/sql',
#  ' sql',
#  ' web services-wsdl',
#  ' oauth',
#  ' microservices',
#  ' mongodb',
#  ' jenkins',
#  ' soap uddi',
#  ' soap ui',
#  ' axis2',
#  ' aws',
#  ' rest api',
#  ' jax-rs',
#  ' jersey',
#  ' windows xp.',
#  ' core java',
#  ' j2se',
#  ' servlets',
#  ' jsp',
#  ' yui',
#  ' hibernate',
#  ' spring framework',
#  ' xml',
#  ' mysql',
#  ' eclipse',
#  ' rest web services',
#  ' oauth',
#  ' firebird tool',
#  ' cassandra',
#  ' postgres db',
#  ' soap',
#  ' soap ui',
#  ' jboss',
#  ' spring web flow',
#  ' pl/sql',
#  ' dozer frame work',
#  ' db2',
#  ' jquery',
#  ' ajax',
#  ' java 1.5',
#  ' j2ee',
#  ' rmi',
#  ' spring frame work',
#  ' soap',
#  ' hibernate',
#  ' html 4.x',
#  ' css2.x',
#  ' javascript',
#  ' jquery',
#  ' ajax',
#  ' json',
#  ' xml',
#  ' yui',
#  ' multi-threading',
#  ' apache tomcat server',
#  ' jpa',
#  ' soap ui',
#  ' rest web services',
#  ' spring web flow',
#  ' boot strap.',
#  ' java',
#  ' j2se',
#  ' jsp',
#  ' servlet',
#  ' sql',
#  ' oracle9i',
#  ' jdbc',
#  ' swing',
#  ' eclipse',
#  ' html',
#  ' sdlc',
#  ' ms office',
#  ' windows',
#  ' ajax',
#  ' jpa annotations',
#  ' soap web services',
#  ' wsdl',
#  ' uddi',
#  ' sax',
#  ' dom',
#  ' java',
#  '\xa0j2ee',
#  ' jdk 1.7/1.8',
#  ' rcp',
#  ' aws\xa0sdk',
#  '\xa0ext js',
#  ' git',
#  ' swing',
#  ' jfc',
#  ' spring 4.x',
#  ' aws\xa0sns/sqs',
#  ' hibernate4.x',
#  ' scala',
#  ' core java',
#  ' soap/rest',
#  ' web services',
#  ' python 2.7',
#  ' javascript',
#  ' clojure',
#  ' uml',
#  ' html5',
#  ' css',
#  ' sass',
#  ' rad 7',
#  ' was 8 wsdl',
#  ' sdk’s',
#  ' jira 5.x/6.x',
#  ' jaxb',
#  ' linux',
#  ' jax-ws',
#  ' jax rpc',
#  ' jms',
#  ' unix',
#  ' selenium nosql(mongodb)',
#  ' angularjs1.5',
#  ' reactjs',
#  ' ajax',
#  ' apache jmeter',
#  ' jquery',
#  ' mule\xa0esb\xa0junit',
#  ' maven',
#  ' emr.',
#  ' j2ee',
#  ' springmok4.x',
#  ' spring mvc',
#  ' hibernate 3.x',
#  ' angularjs',
#  ' jquery',
#  ' json',
#  ' servlets 2.3',
#  ' jdbc',
#  ' ajax',
#  ' web services',
#  ' soap',
#  ' xml',
#  ' java beans',
#  ' xstream',
#  ' net tool',
#  ' apache cxf 2.6',
#  ' apache poi',
#  ' ext js',
#  ' jquery',
#  ' javascript',
#  ' jboss',
#  ' agile methodology',
#  ' design patterns',
#  ' svn',
#  ' apache maven',
#  ' junit',
#  ' html unit',
#  ' xslt',
#  ' html/dhtml.',
#  '  core java/j2ee',
#  ' servlets',
#  ' java spring',
#  ' jstl',
#  ' ejb',
#  ' jms',
#  ' xml',
#  ' xslt',
#  ' jdbc',
#  ' ajax',
#  ' ibm websphere application server 7.0',
#  ' oracle 10g',
#  ' wsad',
#  ' ibm mq',
#  ' html',
#  ' css',
#  ' javascript',
#  ' eclipse',
#  ' uml',
#  ' rational rose',
#  ' windows xp',
#  ' cvs',
#  ' junit',
#  ' ant',
#  ' adobe flex',
#  ' visio.',
#  ' core java',
#  ' java 1.6',
#  ' spring',
#  ' hibernate',
#  ' svn',
#  ' apache',
#  ' eclipse 3.3',
#  ' jndi',
#  ' log4j',
#  ' junit',
#  ' xml',
#  ' xsd',
#  ' angularjs',
#  ' node.js',
#  ' jquery',
#  ' html 5',
#  ' bootstrap',
#  ' javascript',
#  ' web logic application server',
#  ' oracle',
#  ' windows xp',
#  ' rest api',
#  ' netbeans',
#  ' unix.',
#  ' java',
#  ' j2ee',
#  ' jsp',
#  ' spring',
#  ' hibernate',
#  ' jms',
#  ' xml',
#  ' web services',
#  ' soap',
#  ' ajax',
#  ' html',
#  ' javascript',
#  ' css',
#  ' log4j',
#  ' junit',
#  ' maven',
#  ' websphere',
#  ' application server',
#  ' eclipse',
#  ' oracle.',
#  ' corejava',
#  ' java beans',
#  ' jsp',
#  ' jbuilder',
#  ' javascript',
#  ' servlets',
#  ' jdbc',
#  ' log4j',
#  ' xml',
#  ' xslt',
#  ' ',
#  ' waterfall-agile',
#  ' ms office',
#  ' ms project',
#  ' ms visio',
#  ' mysql',
#  ' ibm db2 10.5',
#  ' postman 4.8',
#  ' informatica powercenter 9.6.x',
#  ' tableau 8.3.11',
#  ' ibm websphere',
#  ' apache tomcat',
#  ' ibm maximo 7.6',
#  ' rational requisite pro',
#  ' hp alm',
#  ' hp uft 12.0',
#  ' cucumber',
#  ' load runner',
#  ' sap – erp 6.0',
#  ' sap – ariba',
#  ' html',
#  ' xml',
#  ' jira 7.2.4',
#  ' twilio 2.0.0',
#  ' agile',
#  ' apache hadoop',
#  ' hdfs',
#  ' apache hive',
#  ' apache kafka',
#  ' jira 6.2',
#  ' sql',
#  ' ms office',
#  ' ms project',
#  ' selenium',
#  ' cucumber',
#  ' power bi',
#  ' jira 7',
#  ' sap – ariba spend management suite',
#  ' waterfall',
#  ' erwin 9.5',
#  ' rational requisite pro',
#  ' oracle 11g',
#  ' ms office',
#  ' microstrategy 9.5x',
#  ' oracle netsuite',
#  ' sap – erp',
#  ' sap - ariba',
#  ' agile (safe)',
#  ' mysql',
#  ' hadoop',
#  ' apache flume and scoop',
#  ' apache spark',
#  ' apache tomcat',
#  ' cucumber',
#  ' selenium',
#  ' xml',
#  ' html',
#  ' json',
#  ' http',
#  ' rest api',
#  ' ms visio',
#  ' load runner',
#  ' tableau 7.0.12',
#  ' ms project',
#  ' agile',
#  ' jira 5.0',
#  ' informatica powercenter 9.0.x',
#  ' hp alm',
#  ' hp qtp 11.0',
#  ' oracle 10g',
#  ' crystal',
#  ' waterfall-sdlc',
#  ' oracle 10g',
#  ' microsoft sql server',
#  ' ssis',
#  ' ms office suite',
#  ' erwin 8',
#  ' ms project',
#  ' waterfall',
#  ' windows',
#  ' microsoft sql server',
#  ' sql server profiler',
#  ' visual studio',
#  ' ssis',
#  ' crystal',
#  '·  java',
#  ' j2ee 1.6',
#  ' agile scrum',
#  ' spring ioc',
#  ' spring mvc',
#  ' spring restful web service',
#  ' hibernate 3.2',
#  ' jms',
#  ' ajax',
#  ' struts jsp',
#  ' oracle',
#  ' servlets',
#  ' angularjs',
#  ' javascript',
#  ' nodejs',
#  '',
#  ' uml',
#  ' css',
#  ' java\xa0script',
#  ' html 5',
#  ' ',
#  ' ant',
#  ' windows',
#  ' git',
#  ' log4j.',
#  ' java',
#  ' j2ee 1.6',
#  ' spring 3.2',
#  ' spring ioc',
#  ' hibernate',
#  ' struts mvc',
#  ' mysql',
#  ' jsp',
#  ' html 5',
#  ' css',
#  ' jquery',
#  ' java\xa0mail',
#  ' ajax',
#  ' cvs',
#  ' xml',
#  ' xsd',
#  ' mongodb',
#  ' oracle',
#  ' agile scrum',
#  ' tdd',
#  ' soap (apache cxf)',
#  ' wsdl',
#  ' junit',
#  ' ant',
#  ' uml',
#  ' unix',
#  ' git',
#  ' oracle 11g',
#  ' jenkins',
#  ' angular js',
#  ' javascript',
#  ' nodejs..',
#  ' jdk 1.5',
#  ' j2ee',
#  ' ejb 3.0',
#  ' jndi 1.2',
#  ' hibernate 2.1',
#  ' struts 1.3',
#  ' html',
#  ' javascript',
#  ' angular',
#  ' xml',
#  ' css',
#  ' junit',
#  ' uml',
#  ' ireport 2.0 and 4.0',
#  ' web services',
#  ' soap',
#  ' wsdl',
#  ' uddi',
#  ' axis 2',
#  ' ajax',
#  ' ant',
#  ' eclipse 3.3',
#  ' ibm web sphere 6.1',
#  ' db2',
#  ' subversion',
#  ' linux.',
#  '\xa0java',
#  '\xa0j2ee',
#  ' jsp',
#  ' jsf',
#  ' servlets',
#  ' struts 2.0',
#  ' spring 2.0',
#  ' jdbc 3.0',
#  ' web services',
#  'angular',
#  'javascript',
#  ' xml',
#  ' jndi',
#  ' hibernate 3.0',
#  ' jms',
#  ' weblogic',
#  '  aws',
#  ' eclipse',
#  ' oracle 10g',
#  ' html',
#  ' rational rose ide',
#  ' junit 4.0',
#  ' log4j',
#  ' javascript 1.2',
#  ' xml/xslt',
#  ' sax',
#  ' dom.',
#  '\xa0java/j2ee (jdk 1.5/1.7)',
#  ' spring',
#  ' spring mvc',
#  ' hibernate',
#  'angular',
#  ' jms',
#  ' rest web services',
#  ' junit',
#  ' jsf',
#  ' maven',
#  ' rest',
#  ' xml',
#  ' json',
#  ' jax-rs',
#  ' jira',
#  ' stored procedures',
#  ' apigee',
#  ' easy mock',
#  ' etl',
#  ' uml',
#  ' jpa',
#  ' jenkins',
#  ' apache',
#  ' java',
#  ' j2ee',
#  ' j2ee',
#  ' jsp',
#  ' rational rose',
#  ' servlets',
#  ' struts framework',
#  ' javascript',
#  ' oracle and bea weblogic server',
#  ' ant',
#  ' svn',
#  ' log4j.',
#  ' spring core',
#  ' spring ioc',
#  ' spring mvc ',
#  ' javascript',
#  ' jquery',
#  ' json',
#  ' spring dao ',
#  ' spring boot ',
#  ' spring batch',
#  ' spring security',
#  ' spring integration',
#  ' spring-hibernate integration framework',
#  ' jsp',
#  ' oracle',
#  ' pl/sql',
#  ' xml',
#  ' aws (ec2',
#  ' vpc)',
#  ' spring web flow',
#  ' drools',
#  ' maven',
#  '  junit',
#  ' rest web service',
#  ' html',
#  ' css',
#  ' sass',
#  ' ajax',
#  ' jira',
#  ' angular js',
#  ' npm/bower.',
#  ' spring',
#  ' hibernate',
#  ' web services',
#  ' jax-rs',
#  ' junit',
#  ' soap',
#  ' ui',
#  ' sql',
#  ' jsp',
#  ' jdbc',
#  ' json',
#  ' javascript',
#  ' jquery',
#  ' ajax',
#  ' html',
#  ' css',
#  ' angular js',
#  ' pl/sql',
#  ' postgresssql maven',
#  ' log4j',
#  ' jenkins',
#  ' jira',
#  ' jms',
#  ' apache axis',
#  ' apache cxf',
#  ' git',
#  ' unix',
#  ' agile-scrum',
#  ' oracle',
#  ' tomcat',
#  ' drools.',
#  ' j2ee',
#  ' hibernate',
#  ' spring mvc framework',
#  ' uml',
#  ' servlet',
#  ' jsp',
#  ' jsf',
#  ' ajax',
#  ' dhtml',
#  ' java script',
#  ' jquery',
#  ' json',
#  '  ejb (session and message driven beans)',
#  ' eclipse ',
#  ' ibm mq',
#  ' my sql',
#  ' jboss',
#  ' drools',
#  ' junit',
#  ' mockito',
#  ' maven',
#  ' web services',
#  ' dao',
#  ' web sphere.',
#  ' java',
#  ' j2ee design patterns',
#  ' xml',
#  ' css3',
#  ' web sphere',
#  ' struts',
#  ' web services',
#  ' jsp',
#  ' jstl',
#  ' ejb',
#  ' servlet',
#  ' ajax',
#  ' hibernate',
#  ' rad ',
#  ' ibm mq series',
#  ' rest',
#  ' sql server',
#  ' drools',
#  ' unix',
#  ' uml.',
#  ' ejb',
#  ' servlet',
#  ' javascript',
#  ' struts',
#  ' java',
#  ' web logic',
#  ' xml',
#  ' ibatis',
#  ' jsp',
#  ' jboss',
#  ' ant',
#  ' eclipse',
#  ' oracle.',
#  ' java',
#  ' hibernate',
#  ' struts',
#  ' ejbs',
#  ' jsp',
#  ' servlet',
#  ' junit',
#  ' ant',
#  ' mysql',
#  ' log4j',
#  ' json',
#  ' html',
#  ' javascript',
#  ' jquery.',
#  '  java 1.7',
#  ' j2ee',
#  ' net beans 7.4',
#  ' html',
#  ' css',
#  'aws',
#  ' javascript',
#  ' jquery',
#  ' struts 1.2',
#  ' jdbc',
#  ' jndi',
#  ' oracle 11g',
#  ' glassfish 3.2',
#  '  apache\xa0camel\xa0 ',
#  'ant',
#  ' junit4',
#  ' rabbit mq',
#  ' log 4j',
#  ' backbone\xa0js',
#  ' pl/sql developer',
#  ' itext',
#  ' apache poi',
#  ' microservices.',
#  ' jdk 1.5',
#  ' j2ee',
#  ' ejb 2.0',
#  ' jndi 1.2',
#  ' hibernate 2.1',
#  ' spring 2.0',
#  ' html',
#  '  javascript',
#  ' xml',
#  ' css',
#  ' node.js junit',
#  ' uml',
#  ' mq series',
#  ' web services',
#  ' soap',
#  ' wsdl',
#  '  backbone\xa0js ',
#  ...]

# %%
len(all_skills)
# Out:
# 16643

# %%
all_skills = set(all_skills)

# %%
len(all_skills)
# Out:
# 3559

# %%
def get_matches():
    all_file_matches = list()
    files = list(resume_entities['file'])
    for file in tqdm.tqdm(files):
        text = read_file(file)
        all_matches = dict()
        for skill in all_skills:
            skill = skill.strip()
            if skill == '':
                continue
            matches = [_.span() for _ in re.finditer(r'\b(%s)\b' % re.escape(skill), text)]
            if len(matches)>0:
                all_matches[skill] = matches
        all_file_matches.append(all_matches)
    return all_file_matches

# %%
all_skill_matches = get_matches()
# Out:
# 100%|██████████| 228/228 [05:08<00:00,  1.35s/it]

# %%
resume_entities['skill_matches'] = all_skill_matches

# %%
def get_entity_indexes(doc):
    text = read_file(doc['file']).lower()
    matches = list()
    print(doc['file'])
    for col in ['skill_matches','org_matches','experience','person name','city']:
        entities = doc[col]
        if col == 'skill_matches':
            col = 'skill'
            #entities = literal_eval(entities)
        elif col=='org_matches':
            col = 'org'
            #entities = literal_eval(entities)
        elif col == 'person name':
            col = 'person'
        if entities == 'None':
            continue
        if type(entities) in [dict,list]:
            for ent in entities:
                matches.extend([_.span()+(col,) for _ in re.finditer(r'\b(%s)\b' % re.escape(ent.lower().strip()), text)])
        elif type(entities) is str:
            temp = [_.span()+(col,) for _ in re.finditer(r'\b(%s)\b' % re.escape(entities.lower().strip()), text)]
            if len(temp)>0:
                matches.append(temp[0])
        else:
            continue
    return matches

# %%
all_entities = list()
for ix in resume_entities.index:
    doc = resume_entities.loc[ix]
    all_entities.append(get_entity_indexes(doc))
# Out:
# Venkat_BA.docx
# Shashank.docx
# Anudeep N_Sr Java Developer.docx
# ram nandyala.docx
# Neha Mugghala.docx
# chenna kesava.docx
# Utthan Silawal12.docx
# Yohan BSA.docx
# Madhu_BA_AW.DOCX
# KIRAN KUMAR.docx
# avinash G.docx
# Harika_java.docx
# Mounika_P.docx
# HARI_Sr.Java Developer.docx
# RaviRaju_Resume.docx
# B Shaker-Sr BSA-Scrum Master .docx
# Vamshi Teja_Business Analyst.docx
# VIJETHA G.docx
# SaravanaKumar.docx
# Abiral_Pandey_Fullstack_Java.docx
# Manohar Reddy.docx
# Syed_Zia_Ashraf.docx
# srinivas b.docx
# Gururaja Murthy PMCPCSM.docx
# Madhuri Pawar.docx
# Sr. Business Analyst.docx
# Naveen Kumar Bandela.docx
# mohid_rj.docx
# Nikki_Nimmagadd.docx
# Chandler_BA.docx
# Ramteja Motupalli.docx
# Sri Gati.docx
# Rajesh_k.docx
# Ashok Jayakumar - PM.docx
# Sahithi K.docx
# Deepika Chintalapati.docx
# RaviBurra_Certified PM_DevOps.docx
# Business Analyst_GHyma.docx
# Vivek.BSA.docx
# Gokul Selvam S PM.docx
# Naveen Arora.docx
# jagadeesh k.docx
# BA Kiran.docx
# Gopi.docx
# Raja Santhosam_PM Scrum Master.DOCX
# Resume - PM Agile-Scrum.docx
# Satish Uduta.docx
# Othman - Project Manager.docx
# Satish Reddy.docx
# Priya_Sharma.docx
# Sai Krishna BA.docx
# Nandini_Resume.docx
# Vivek Joshi_CV.docx
# indrakaran soma.docx
# Priyanka Sr BSA Resume.docx
# Shaker Resume.docx
# Tarun Resume.docx
# Rajendra-PMP-CSM.docx
# Akhil.profile.docx
# Mohamad Jamil.docx
# Pierre John.docx
# Derik.docx
# Dantu Padmasri - Project Manager.docx
# Vamshi L.docx
# Resume Vishal PM - MSIS, PMP-PMI.docx
# Deepika DC.docx
# MounikaReddy.docx
# manish_singh_resume.docx
# Smita Kamble_Resume.docx
# nithin katapally.docx
# harish S.docx
# ravikiran JALASUTRAPU.docx
# Nilesh-resume_1_phplead.docx
# AnilAgarwal.docx
# Francis Gomes Resume.docx
# Avathika BA-Healthcare_.docx
# Shiva G-Java Resume.docx
# madhuri R.docx
# Komala BSA Resume.docx
# Tanmay_Dam_Resume_BA.docx
# Randy Adams.docx
# Balakrishna Sudabathula.docx
# Amulya Komatineni.docx
# Krishnapriya_BA.docx
# Ravi Pattar- Sr. Agile Program manager.docx
# Pavan Kumar Full Stack Java Developer.docx
# Krishna_BSA.docx
# Sai Srinivas_Sr_Java_Developer.docx
# employer_mounika details.docx
# Samir Naik-NJ - Mar 2018-V3.0.docx
# Vishnu J.docx
# Bharatha BA Resume.docx
# Vijay Bhargav.docx
# Praveen B.docx
# Vikash_BA_Ab.docx
# Manohar B.docx
# sai k.docx
# TeresaNeetipudi IT BA.DOCX
# Varun.docx
# Priya B.docx
# PM RESUME.docx
# Harish K.docx
# madhuri_java.docx
# Kuppurajbabu_BA.docx
# Kumar Raj.docx
# Kashyap K. Vora resume.docx
# Mahesh_Kamath_PM (1).docx
# Naren Sr.BA.docx
# Mitali Barman_Resume.docx
# Manikanta P.docx
# Adelina_Erimia_PMP1.docx
# Jennifer  M. Conte.docx
# Tarun_Developer.docx
# Sougandh_Java Fullstack Developer.docx
# Mani_Hadoop.docx
# Balaji Gopalakrishnan Project Manager.docx
# Jagan S Iyer PM.docx
# Dave.docx
# Mounika health care resume.docx
# Prashant Chawda_resume.docx
# Pranay P.docx
# Vinay.D_Resume.docx
# Yugesh_Resume.docx
# komal patel.docx
# Sarath M.docx
# manohar.B.docx
# kalyan das.docx
# Sai kumar.docx
# SAURABH_PM.docx
# ParthMPatel_BA.docx
# Samir Naik-NJ - Feb 2018-V6.0.docx
# Naren Sr.BA .docx
# Krishna Sr. BSA Resume.docx
# Ramachandra EDA.docx
# Tarun RESUME-BSAT.docx
# Sudhakar Reddy.docx
# ram krishna.docx
# BA - Navneet.docx
# Pavan Sr Business Analyst resume.docx
# Tejaswi-resume.docx
# Srivatsan_Project_Manager.docx
# Ashwini J2EE Developer.docx
# Rashmitha R.docx
# Shail_Tank-Business Analyst .docx
# Atul_Mathur_Resume.docx
# Drakshajavauidev.docx
# Nikith Reddy.docx
# Praveen T.docx
# Naveen.S_Resume.docx
# BA with INV.docx
# Resume_Spoorti Pandit_BSA.docx
# Saiteja G.docx
# Alekhya Resume.docx
# Shelly Woods.docx
# Resume - Sr PM.docx
# Krishna Kuruvella.docx
# Ravi Reddy.docx
# Vishnu BA Resume.docx
# ronith s.docx
# Rohanu Resume.docx
# Sravani Battu.docx
# Sumanth Manne Java Developer.docx
# Ujvala BA Feb 20.docx
# Uday_Maripelly.docx
# Krishna_SrJava.docx
# Achyuth Resume_8.docx
# Sahas BA Resume.docx
# Dhanalaxmi -BA.docx
# Bharat Arora_CV_PMP _ ERP1.docx
# Rao_Java.docx
# Bapuji Hadoop developer.docx
# Jayadattaperi N.docx
# Varun Kumar.docx
# jeck P.docx
# Jimi_Desai_PM.docx
# Mehul.docx
# Sravani Singirikonda.docx
# Tushar Patel.docx
# Amar Sr BSA.docx
# Gautami Bulusu Mobile Testing 3.docx
# Niteesh Java Developer.docx
# Vishal S..docx
# Mohammad Resume.docx
# vema reddy.docx
# nithin Reddy.docx
# Jaya prakash.docx
# Amrinder Business Analyst.docx
# Resume2018March.docx
# Resume - Kishore Kotapati - 218E - BA.docx
# Raju Goduguchinta_Technical Program Manager.docx
# Spoorthi Finance BSA Resume.docx
# Shiuli Mahmud.docx
# Naresh V.docx
# Tarun.docx
# RAMYA BUSINESS ANALYST RESUME.docx
# vikas java.docx
# BA - Abhishek.docx
# Sharath Java.docx
# mahesh_Java.docx
# Reddemma_Lankipalle.docx
# mounika BA resume 7.docx
# Anil Krishna Mogalaturthi.docx
# Murali_Project Manager QA.DOCX
# sanjay kumar.docx
# KY BA PM UPDATED RESUME .docx
# Brahma-Resume (BA).docx
# Robinson.docx
# venu b.docx
# Ami Jape.docx
# Siddhartha Gandroju.docx
# Adhi Gopalam - SM.docx
# Pankaj BSA.docx
# Ranjan_Project Manager-Scrum Master.docx
# CHETAN_Sr Java Developer.docx
# Santosh Arugula BA.docx
# Akhil_Sr BSA.docx
# Sundar_Java_8+ Years..docx
# SUNITHA Project Manager (1).docx
# sairithvik alla.docx
# Haarika_BA.docx
# AjayKumar.docx
# Nikhil.docx
# B Suresh Kumar_Project Manager_1.docx
# Harshitha Challa.docx
# Venkata_Sr.PHP_Developer.docx
# V Ashok A.docx
# Navneeth Resume.docx
# Vishnu Java dev.docx

# %%
resume_entities['entities'] = all_entities

# %%
resume_entities.columns
# Out:
# Index(['file', 'skills', 'phone', 'Organisations', 'Institutes', 'email',
#        'experience', 'person name', 'city', 'skills_len', 'orgs_len',
#        'skill_matches', 'org_matches', 'entities'],
#       dtype='object')

# %%
resume_entities.to_csv('resume_entities1.csv',index=False)

# %%
resume_entities['entities'] = [literal_eval(_) for _ in resume_entities['entities']]

# %%
resume_entities[(resume_entities['city']!='None')].shape
# Out:
# (32, 14)

# %%
train_data = resume_entities[(resume_entities['city']!='None')]

# %%
train_data.shape
# Out:
# (32, 14)

# %%
def write_train_data(file,labels,fp):
    newline =' '
    text = read_file(file)
    #data_tagged = 32
    count=-1
    count+=1
    #if count == data_tagged:
    #    break
    ann_last = 0
    print(labels)
    dtype = [('start', int), ('end', int), ('label', 'U15')]
    values = list()
    for label in labels:
        values.append((label[0],label[1],label[2]))
    temp_list = np.array(values,dtype=dtype)
    temp_list = np.sort(temp_list,order=['start'])
    for ann in temp_list:
        print(ann_last)
        outside_words = text[ann_last:ann[0]].split(' ')
        for word in outside_words:
            if word != '':
                fp.write(word + ' ' + 'O'+'\n')
        inside_words = text[ann[0]:ann[1]].split(' ')
        label = ann[2]
        ix = 0
        for word in inside_words:
            if word != ' ':
                if ix == 0:
                    fp.write(word+ ' B-'+label+'\n')
                else:
                    fp.write(word + ' I-'+label+'\n')
                ix+=1
        ann_last = ann[1]
    outside_words = text[ann_last:len(text)].split(' ')
    for word in outside_words:
        if word != '':
            fp.write(word + ' ' + 'O'+'\n')
    fp.write("\n")

# %%
with open('train_resume.bie','w') as fp:
    for ix in train_data.index:
        doc = train_data.loc[ix]
        write_train_data(doc['file'],doc['entities'],fp)
# Out:
# [(3204, 3211, 'skill'), (7478, 7485, 'skill'), (3523, 3546, 'skill'), (13737, 13760, 'skill'), (33, 34, 'skill'), (12280, 12281, 'skill'), (12997, 12998, 'skill'), (13878, 13879, 'skill'), (13887, 13888, 'skill'), (4701, 4712, 'skill'), (3195, 3202, 'skill'), (7469, 7476, 'skill'), (1155, 1158, 'skill'), (643, 655, 'skill'), (7180, 7192, 'skill'), (10231, 10243, 'skill'), (15092, 15104, 'skill'), (14664, 14680, 'skill'), (11540, 11554, 'skill'), (7125, 7135, 'skill'), (15037, 15047, 'skill'), (2285, 2293, 'skill'), (2254, 2259, 'skill'), (10602, 10607, 'skill'), (2233, 2246, 'skill'), (13067, 13083, 'skill'), (17298, 17301, 'skill'), (314, 317, 'skill'), (1264, 1267, 'skill'), (2113, 2116, 'skill'), (6794, 6797, 'skill'), (10466, 10469, 'skill'), (13574, 13577, 'skill'), (17508, 17511, 'skill'), (12280, 12284, 'skill'), (12997, 13001, 'skill'), (13878, 13882, 'skill'), (13887, 13891, 'skill'), (794, 798, 'skill'), (4544, 4548, 'skill'), (4696, 4700, 'skill'), (17061, 17065, 'skill'), (7444, 7447, 'skill'), (2932, 2935, 'skill'), (12155, 12158, 'skill'), (518, 525, 'skill'), (2590, 2597, 'skill'), (2876, 2883, 'skill'), (3104, 3111, 'skill'), (3241, 3248, 'skill'), (3506, 3513, 'skill'), (6032, 6039, 'skill'), (10776, 10783, 'skill'), (10804, 10811, 'skill'), (11186, 11193, 'skill'), (12085, 12092, 'skill'), (12174, 12181, 'skill'), (12347, 12354, 'skill'), (12540, 12547, 'skill'), (13726, 13733, 'skill'), (13782, 13789, 'skill'), (14874, 14881, 'skill'), (15357, 15364, 'skill'), (15588, 15595, 'skill'), (17025, 17032, 'skill'), (17158, 17165, 'skill'), (17589, 17596, 'skill'), (17621, 17628, 'skill'), (18187, 18194, 'skill'), (18271, 18278, 'skill'), (18299, 18306, 'skill'), (2055, 2076, 'skill'), (4501, 4522, 'skill'), (17352, 17369, 'skill'), (2251, 2259, 'skill'), (10599, 10607, 'skill'), (4725, 4734, 'skill'), (3523, 3528, 'skill'), (4538, 4543, 'skill'), (4701, 4706, 'skill'), (4831, 4836, 'skill'), (8720, 8725, 'skill'), (12364, 12369, 'skill'), (13737, 13742, 'skill'), (8823, 8826, 'skill'), (11877, 11880, 'skill'), (1135, 1150, 'skill'), (16282, 16288, 'skill'), (290, 298, 'skill'), (2134, 2142, 'skill'), (4571, 4579, 'skill'), (6865, 6873, 'skill'), (8628, 8636, 'skill'), (10405, 10413, 'skill'), (10415, 10423, 'skill'), (10437, 10445, 'skill'), (10524, 10532, 'skill'), (10795, 10803, 'skill'), (7510, 7516, 'skill'), (489, 492, 'skill'), (13067, 13070, 'skill'), (15701, 15704, 'skill'), (13884, 13888, 'skill'), (13864, 13865, 'skill'), (16659, 16666, 'skill'), (4714, 4720, 'skill'), (6374, 6387, 'skill'), (3081, 3087, 'skill'), (3173, 3179, 'skill'), (13884, 13891, 'skill'), (436, 438, 'skill'), (2578, 2580, 'skill'), (7628, 7630, 'skill'), (11527, 11529, 'skill'), (13987, 13989, 'skill'), (7331, 7344, 'skill'), (15243, 15256, 'skill'), (3523, 3534, 'skill'), (4831, 4842, 'skill'), (12364, 12375, 'skill'), (13737, 13748, 'skill'), (8820, 8826, 'skill'), (2247, 2259, 'skill'), (7125, 7128, 'skill'), (7316, 7319, 'skill'), (7331, 7334, 'skill'), (13871, 13874, 'skill'), (15037, 15040, 'skill'), (15228, 15231, 'skill'), (15243, 15246, 'skill'), (17260, 17263, 'skill'), (17332, 17335, 'skill'), (962, 965, 'skill'), (1135, 1138, 'skill'), (16944, 16947, 'skill'), (478, 484, 'skill'), (7129, 7135, 'skill'), (15041, 15047, 'skill'), (10875, 10885, 'skill'), (2044, 2047, 'skill'), (9427, 9430, 'skill'), (17910, 17920, 'skill'), (13219, 13224, 'skill'), (7076, 7080, 'skill'), (15383, 15387, 'skill'), (2519, 2522, 'skill'), (4097, 4100, 'skill'), (8369, 8372, 'skill'), (13884, 13887, 'skill'), (439, 446, 'skill'), (460, 467, 'skill'), (901, 908, 'skill'), (3126, 3133, 'skill'), (10062, 10069, 'skill'), (11237, 11244, 'skill'), (11547, 11554, 'skill'), (11572, 11579, 'skill'), (14418, 14425, 'skill'), (17949, 17956, 'skill'), (4393, 4396, 'skill'), (4593, 4596, 'skill'), (5120, 5123, 'skill'), (5270, 5273, 'skill'), (9419, 9422, 'skill'), (9514, 9517, 'skill'), (9642, 9645, 'skill'), (13299, 13302, 'skill'), (6408, 6429, 'skill' ...
# 0
# 14
# 34
# 37
# 87
# 298
# 317
# 438
# 446
# 467
# 484
# 492
# 525
# 655
# 798
# 908
# 965
# 1138
# 1150
# 1158
# 1256
# 1267
# 1580
# 2047
# 2076
# 2116
# 2142
# 2246
# 2246
# 2259
# 2259
# 2259
# 2293
# 2522
# 2580
# 2597
# 2771
# 2883
# 2887
# 2916
# 2935
# 3087
# 3111
# 3133
# 3179
# 3202
# 3211
# 3219
# 3219
# 3248
# 3252
# 3338
# 3459
# 3513
# 3528
# 3534
# 3546
# 3534
# 3609
# 3704
# 4100
# 4396
# 4522
# 4522
# 4543
# 4548
# 4579
# 4596
# 4700
# 4706
# 4712
# 4712
# 4720
# 4734
# 4799
# 4836
# 4842
# 4842
# 4866
# 4935
# 4999
# 5123
# 5273
# 6039
# 6387
# 6429
# 6797
# 6873
# 6994
# 7019
# 7066
# 7080
# 7128
# 7135
# 7135
# 7192
# 7319
# 7327
# 7334
# 7344
# 7407
# 7447
# 7476
# 7485
# 7493
# 7493
# 7516
# 7630
# 7769
# 7793
# 7826
# 8372
# 8610
# 8636
# 8725
# 8808
# 8826
# 8826
# 8862
# 9042
# 9169
# 9279
# 9299
# 9422
# 9430
# 9517
# 9645
# 10069
# 10243
# 10413
# 10423
# 10445
# 10469
# 10532
# 10607
# 10607
# 10783
# 10803
# 10811
# 10885
# 11193
# 11244
# 11277
# 11323
# 11529
# 11554
# 11554
# 11579
# 11607
# 11684
# 11852
# 11865
# 11873
# 11880
# 11897
# 12092
# 12096
# 12139
# 12158
# 12181
# 12281
# 12284
# 12354
# 12369
# 12375
# 12375
# 12547
# 12998
# 13001
# 13070
# 13083
# 13105
# 13224
# 13302
# 13577
# 13701
# 13733
# 13742
# 13748
# 13760
# 13748
# 13789
# 13865
# 13874
# 13878
# 13882
# 13879
# 13882
# 13887
# 13888
# 13891
# 13888
# 13891
# 13913
# 13989
# 14425
# 14680
# 14881
# 15040
# 15047
# 15047
# 15104
# 15231
# 15239
# 15246
# 15256
# 15319
# 15364
# 15387
# 15427
# 15439
# 15454
# 15595
# 15704
# 16288
# 16666
# 16947
# 17032
# 17065
# 17165
# 17263
# 17271
# 17301
# 17335
# 17369
# 17511
# 17596
# 17628
# 17920
# 17920
# 17956
# 18194
# 18278
# 18306
# [(1990, 1993, 'skill'), (3738, 3741, 'skill'), (3861, 3864, 'skill'), (3985, 3988, 'skill'), (4046, 4049, 'skill'), (5204, 5207, 'skill'), (5326, 5329, 'skill'), (7174, 7177, 'skill'), (7353, 7356, 'skill'), (8626, 8629, 'skill'), (2615, 2616, 'skill'), (2644, 2645, 'skill'), (2858, 2859, 'skill'), (4586, 4587, 'skill'), (6580, 6581, 'skill'), (8487, 8488, 'skill'), (10350, 10351, 'skill'), (12729, 12730, 'skill'), (12741, 12742, 'skill'), (12757, 12758, 'skill'), (640, 646, 'skill'), (2180, 2186, 'skill'), (3088, 3094, 'skill'), (220, 224, 'skill'), (2706, 2710, 'skill'), (2835, 2839, 'skill'), (5052, 5056, 'skill'), (12717, 12721, 'skill'), (14126, 14130, 'skill'), (1242, 1249, 'skill'), (2999, 3006, 'skill'), (3955, 3962, 'skill'), (4663, 4670, 'skill'), (6706, 6713, 'skill'), (10144, 10151, 'skill'), (10449, 10456, 'skill'), (12784, 12791, 'skill'), (11711, 11715, 'skill'), (6305, 6311, 'skill'), (7155, 7161, 'skill'), (8391, 8397, 'skill'), (969, 979, 'skill'), (5083, 5093, 'skill'), (5184, 5194, 'skill'), (5295, 5305, 'skill'), (1051, 1056, 'skill'), (6305, 6310, 'skill'), (6342, 6347, 'skill'), (14243, 14248, 'skill'), (428, 431, 'skill'), (2824, 2827, 'skill'), (6118, 6121, 'skill'), (6247, 6250, 'skill'), (10682, 10685, 'skill'), (11347, 11350, 'skill'), (12871, 12874, 'skill'), (13072, 13075, 'skill'), (14164, 14167, 'skill'), (773, 784, 'skill'), (773, 793, 'skill'), (131, 135, 'skill'), (215, 219, 'skill'), (925, 929, 'skill'), (1839, 1843, 'skill'), (2700, 2704, 'skill'), (4412, 4416, 'skill'), (4567, 4571, 'skill'), (5040, 5044, 'skill'), (6561, 6565, 'skill'), (6836, 6840, 'skill'), (8468, 8472, 'skill'), (10331, 10335, 'skill'), (12711, 12715, 'skill'), (14181, 14185, 'skill'), (2819, 2822, 'skill'), (7301, 7304, 'skill'), (10707, 10710, 'skill'), (11682, 11685, 'skill'), (13097, 13100, 'skill'), (1219, 1221, 'skill'), (6965, 6967, 'skill'), (32, 33, 'skill'), (2614, 2615, 'skill'), (2643, 2644, 'skill'), (2857, 2858, 'skill'), (4573, 4574, 'skill'), (4585, 4586, 'skill'), (4601, 4602, 'skill'), (5047, 5048, 'skill'), (6310, 6311, 'skill'), (6567, 6568, 'skill'), (6579, 6580, 'skill'), (6595, 6596, 'skill'), (8474, 8475, 'skill'), (8486, 8487, 'skill'), (8502, 8503, 'skill'), (10337, 10338, 'skill'), (10349, 10350, 'skill'), (10365, 10366, 'skill'), (12728, 12729, 'skill'), (12740, 12741, 'skill'), (12756, 12757, 'skill'), (12761, 12762, 'skill'), (13100, 13101, 'skill'), (14122, 14123, 'skill'), (602, 609, 'skill'), (10841, 10848, 'skill'), (12800, 12807, 'skill'), (4600, 4603, 'skill'), (6594, 6597, 'skill'), (8501, 8504, 'skill'), (10364, 10367, 'skill'), (12760, 12763, 'skill'), (587, 597, 'skill'), (2712, 2722, 'skill'), (2841, 2851, 'skill'), (7892, 7902, 'skill'), (12859, 12869, 'skill'), (1135, 1140, 'skill'), (1236, 1241, 'skill'), (3013, 3018, 'skill'), (4402, 4407, 'skill'), (4451, 4456, 'skill'), (12793, 12798, 'skill'), (581, 585, 'skill'), (2813, 2817, 'skill'), (6153, 6157, 'skill'), (6252, 6256, 'skill'), (11989, 11993, 'skill'), (12848, 12852, 'skill'), (2608, 2611, 'skill'), (4605, 4608, 'skill'), (6599, 6602, 'skill'), (8506, 8509, 'skill'), (10369, 10372, 'skill'), (13392, 13395, 'skill'), (2385, 2390, 'skill'), (3185, 3190, 'skill'), (12772, 12777, 'skill'), (3157, 3164, 'skill'), (284, 290, 'skill'), (810, 816, 'skill'), (902, 908, 'skill'), (942, 948, 'skill'), (955, 961, 'skill'), (969, 975, 'skill'), (981, 987, 'skill'), (3579, 3585, 'skill'), (3612, 3618, 'skill'), (3696, 3702, 'skill'), (3748, 3754, 'skill'), (3827, 3833, 'skill'), (4577, 4583, 'skill'), (4622, 4628, 'skill'), (4636, 4642, 'skill'), (4649, 4655, 'skill'), (5070, 5076, 'skill'), (5083, 5089, 'skill'), (5095, 5101, 'skill'), (5131, 5137, 'skill'), (5184, 5190, 'skill'), (5214, 5220, 'skill'), (5295, 5301, 'skill'), (5335, 5341, 'skill'), (6134, 6140, 'skill'), (6571, 6577, 'skill'), (6616, 6622, 'skill'), (6630, 6636, 'skill'), (8478, 8484, 'skill'), (8759, 8765, 'skill'), (8823, 8829, 'skill'), (8839, 8845, 'skill'), ( ...
# 0
# 9
# 33
# 36
# 135
# 189
# 219
# 224
# 224
# 244
# 290
# 298
# 302
# 338
# 395
# 431
# 476
# 556
# 585
# 597
# 609
# 612
# 612
# 646
# 653
# 707
# 712
# 733
# 768
# 793
# 780
# 784
# 793
# 784
# 793
# 816
# 821
# 821
# 852
# 856
# 908
# 918
# 929
# 948
# 953
# 953
# 961
# 967
# 967
# 975
# 979
# 979
# 987
# 992
# 1056
# 1098
# 1133
# 1140
# 1151
# 1186
# 1198
# 1209
# 1213
# 1221
# 1241
# 1249
# 1313
# 1319
# 1357
# 1362
# 1394
# 1441
# 1461
# 1476
# 1497
# 1518
# 1538
# 1548
# 1556
# 1578
# 1595
# 1614
# 1619
# 1627
# 1653
# 1700
# 1708
# 1708
# 1721
# 1729
# 1767
# 1822
# 1843
# 1856
# 1880
# 1884
# 1897
# 1902
# 1915
# 1906
# 1915
# 1964
# 1993
# 2004
# 2022
# 2025
# 2025
# 2102
# 2109
# 2171
# 2178
# 2171
# 2178
# 2178
# 2186
# 2197
# 2224
# 2232
# 2259
# 2315
# 2372
# 2380
# 2390
# 2568
# 2584
# 2594
# 2598
# 2611
# 2615
# 2616
# 2628
# 2641
# 2644
# 2645
# 2655
# 2662
# 2704
# 2710
# 2722
# 2727
# 2735
# 2741
# 2761
# 2769
# 2774
# 2783
# 2792
# 2798
# 2817
# 2822
# 2827
# 2839
# 2851
# 2857
# 2858
# 2858
# 2859
# 2865
# 2884
# 2887
# 2887
# 2893
# 2899
# 2905
# 2910
# 2919
# 2940
# 2950
# 2969
# 2980
# 2997
# 3006
# 3011
# 3018
# 3026
# 3055
# 3094
# 3097
# 3097
# 3112
# 3112
# 3155
# 3164
# 3166
# 3175
# 3183
# 3190
# 3196
# 3255
# 3401
# 3432
# 3509
# 3535
# 3540
# 3585
# 3591
# 3591
# 3605
# 3618
# 3623
# 3623
# 3670
# 3679
# 3690
# 3702
# 3707
# 3707
# 3737
# 3741
# 3754
# 3759
# 3759
# 3784
# 3793
# 3833
# 3838
# 3838
# 3860
# 3864
# 3864
# 3907
# 3962
# 3984
# 3988
# 3988
# 4019
# 4049
# 4076
# 4301
# 4339
# 4347
# 4407
# 4416
# 4456
# 4464
# 4571
# 4575
# 4575
# 4574
# 4583
# 4585
# 4587
# 4586
# 4587
# 4592
# 4599
# 4603
# 4603
# 4602
# 4608
# 4613
# 4620
# 4620
# 4628
# 4634
# 4634
# 4642
# 4647
# 4647
# 4655
# 4661
# 4661
# 4670
# 4675
# 4695
# 4682
# 4695
# 4686
# 4695
# 4819
# 4831
# 4859
# 5044
# 5049
# 5048
# 5056
# 5076
# 5081
# 5081
# 5089
# 5093
# 5093
# 5101
# 5106
# 5106
# 5117
# 5122
# 5137
# 5142
# 5190
# 5194
# 5194
# 5203
# 5207
# 5207
# 5220
# 5225
# 5225
# 5275
# 5301
# 5305
# 5305
# 5325
# 5329
# 5329
# 5341
# 5346
# 5346
# 5377
# 5434
# 5467
# 5530
# 5574
# 5649
# 5736
# 5808
# 5819
# 5869
# 5956
# 6121
# 6132
# 6140
# 6157
# 6184
# 6250
# 6256
# 6261
# 6310
# 6311
# 6311
# 6347
# 6430
# 6479
# 6524
# 6565
# 6569
# 6569
# 6568
# 6577
# 6579
# 6581
# 6580
# 6581
# 6586
# 6593
# 6597
# 6597
# 6596
# 6602
# 6607
# 6614
# 6614
# 6622
# 6628
# 6628
# 6636
# 6641
# 6641
# 6653
# 6660
# 6668
# 6677
# 6685
# 6685
# 6693
# 6704
# 6713
# 6719
# 6739
# 6726
# 6739
# 6730
# 6739
# 6746
# 6754
# 6754
# 6759
# 6840
# 6932
# 6944
# 6955
# 6959
# 6967
# 7030
# 7039
# 7078
# 7087
# 7098
# 7101
# 7101
# 7119
# 7161
# 7173
# 7177
# 7177
# 7189
# 7201
# 7218
# 7241
# 7304
# 7310
# 7352
# 7356
# 7356
# 7364
# 7375
# 7378
# 7383
# 7378
# 7392
# 7396
# 7456
# 7463
# 7470
# 7478
# 7488
# 7590
# 7590
# 7669
# 7682
# 7673
# 7682
# 7745
# 7749
# 7749
# 7757
# 7765
# 7799
# 7821
# 7808
# 7821
# 7812
# 7821
# 7834
# 7843
# 7866
# 7902
# 8097
# 8104
# 8119
# 8127
# 8119
# 8127
# 8136
# 8151
# 8179
# 8199
# 8379
# 8397
# 8403
# 8416
# 8472
# 8476
# 8476
# 8475
# 8484
# 8486
# 8488
# 8487
# 8488
# 8493
# 8500
# 8504
# 8504
# 8503
# 8509
# 8516
# 8526
# 8526
# 8535
# 8544
# 8552
# 8558
# 8561
# 8568
# 8575
# 8583
# 8591
# 8618
# 8604
# 8611
# 8618
# 8629
# 8629
# 8635
# 8666
# 8666
# 8765
# 8772
# 8829
# 8834
# 8834
# 8845
# 8851
# 8851
# 8884
# 8950
# 8957
# 9057
# 9073
# 9078
# 9180
# 9186
# 9186
# 9287
# 9287
# 9397
# 9402
# 9402
# 9413
# 9419
# 9419
# 9566
# 9576
# 9585
# 9598
# 9602
# 9606
# 9602
# 9606
# 9674
# 9695
# 9703
# 9780
# 9819
# 9831
# 9836
# 9836
# 9847
# 9853
# 9853
# 9873
# 9938
# 9952
# 10023
# 10014
# 10023
# 10151
# 10178
# 10245
# 10277
# 10335
# 10339
# 10339
# 10338
# 10347
# 10349
# 10351
# 10350
# 10351
# 10356
# 10363
# 10367
# 10367
# 10366
# 10372
# 10377
# 10384
# 10384
# 10392
# 10398
# 10398
# 10406
# 10411
# 10411
# 10420
# 10428
# 10428
# 10436
# 10447
# 10456
# 10462
# 10482
# 10469
# 10482
# 10473
# 10482
# 10489
# 10497
# 10497
# 10502
# 10610
# 10638
# 10649
# 10660
# 10665
# 10672
# 10680
# 10685
# 10692
# 10710
# 10725
# 10778
# 10785
# 10797
# 10808
# 10816
# 10816
# 10848
# 10892
# 10919
# 10929
# 10977
# 10982
# 11021
# 11028
# 11037
# 11037
# 11136
# 11265
# 11269
# 11289
# 11296
# 11305
# 11323
# 11350
# 11397
# 11408
# 11457
# 11463
# 11463
# 11535
# 11541
# 11541
# 11595
# 11601
# 11601
# 11685
# 11709
# 11715
# 11724
# 11772
# 11779
# 11779
# 11783
# 11806
# 11806
# 11815
# 11843
# 11931
# 11937
# 11937
# 11993
# 12001
# 12006
# 12032
# 12125
# 12148
# 12180
# 12300
# 12300
# 12346
# 12346
# 12407
# 12407
# 12515
# 12531
# 12534
# 12534
# 12605
# 12657
# 12715
# 12721
# 12726
# 12730
# 12729
# 12730
# 12738
# 12742
# 12741
# 12742
# 12747
# 12754
# 12758
# 12757
# 12758
# 12763
# 12762
# 12770
# 12777
# 12782
# 12791
# 12798
# 12807
# 12810
# 12810
# 12816
# 12819
# 12819
# 12829
# 12832
# 12832
# 12837
# 12846
# 12852
# 12857
# 12869
# 12874
# 12882
# 12889
# 13000
# 13028
# 13039
# 13050
# 13055
# 13062
# 13070
# 13075
# 13082
# 13100
# 13101
# 13101
# 13127
# 13127
# 13148
# 13188
# 13215
# 13225
# 13273
# 13278
# 13318
# 13325
# 13334
# 13334
# 13395
# 13453
# 13457
# 13477
# 13484
# 13517
# 13523
# 13523
# 13595
# 13601
# 13601
# 13754
# 13777
# 13809
# 13902
# 13906
# 13906
# 13959
# 14017
# 14038
# 14053
# 14070
# 14124
# 14123
# 14130
# 14138
# 14148
# 14156
# 14162
# 14167
# 14173
# 14179
# 14185
# 14192
# 14203
# 14209
# 14214
# 14220
# 14225
# 14232
# 14241
# [(4273, 4276, 'skill'), (23616, 23619, 'skill'), (3667, 3668, 'skill'), (13731, 13732, 'skill'), (19348, 19349, 'skill'), (20151, 20152, 'skill'), (20916, 20917, 'skill'), (21044, 21045, 'skill'), (21183, 21184, 'skill'), (21252, 21253, 'skill'), (21305, 21306, 'skill'), (21881, 21882, 'skill'), (3880, 3886, 'skill'), (14271, 14277, 'skill'), (23175, 23181, 'skill'), (9865, 9872, 'skill'), (17423, 17435, 'skill'), (2676, 2679, 'skill'), (3749, 3753, 'skill'), (5070, 5074, 'skill'), (9881, 9885, 'skill'), (3682, 3685, 'skill'), (2606, 2608, 'skill'), (7967, 7969, 'skill'), (340, 341, 'skill'), (2913, 2914, 'skill'), (2921, 2922, 'skill'), (3666, 3667, 'skill'), (3676, 3677, 'skill'), (3725, 3726, 'skill'), (13730, 13731, 'skill'), (13735, 13736, 'skill'), (13830, 13831, 'skill'), (15448, 15449, 'skill'), (15455, 15456, 'skill'), (16252, 16253, 'skill'), (17496, 17497, 'skill'), (18517, 18518, 'skill'), (18523, 18524, 'skill'), (18848, 18849, 'skill'), (19178, 19179, 'skill'), (19337, 19338, 'skill'), (19347, 19348, 'skill'), (19354, 19355, 'skill'), (19504, 19505, 'skill'), (19879, 19880, 'skill'), (20144, 20145, 'skill'), (20150, 20151, 'skill'), (20307, 20308, 'skill'), (20915, 20916, 'skill'), (21043, 21044, 'skill'), (21182, 21183, 'skill'), (21251, 21252, 'skill'), (21304, 21305, 'skill'), (21880, 21881, 'skill'), (21996, 21997, 'skill'), (22089, 22090, 'skill'), (22336, 22337, 'skill'), (23169, 23170, 'skill'), (23605, 23606, 'skill'), (23625, 23626, 'skill'), (9894, 9897, 'skill'), (17423, 17430, 'skill'), (19918, 19925, 'skill'), (20937, 20944, 'skill'), (20923, 20935, 'skill'), (15003, 15015, 'skill'), (19366, 19381, 'skill'), (20171, 20186, 'skill'), (3888, 3896, 'skill'), (9820, 9828, 'skill'), (17437, 17455, 'skill'), (23175, 23183, 'skill'), (4133, 4138, 'skill'), (15212, 15217, 'skill'), (4179, 4182, 'skill'), (9842, 9845, 'skill'), (3857, 3867, 'skill'), (13675, 13685, 'skill'), (13760, 13770, 'skill'), (15461, 15471, 'skill'), (17461, 17471, 'skill'), (18544, 18554, 'skill'), (19366, 19376, 'skill'), (20171, 20181, 'skill'), (21910, 21920, 'skill'), (22353, 22363, 'skill'), (23642, 23652, 'skill'), (2390, 2393, 'skill'), (14124, 14127, 'skill'), (3997, 4002, 'skill'), (13837, 13842, 'skill'), (3749, 3760, 'skill'), (2959, 2966, 'skill'), (3817, 3824, 'skill'), (18015, 18022, 'skill'), (2680, 2686, 'skill'), (4102, 4108, 'skill'), (5563, 5569, 'skill'), (8556, 8562, 'skill'), (9772, 9778, 'skill'), (2188, 2194, 'skill'), (2484, 2490, 'skill'), (2696, 2702, 'skill'), (4148, 4154, 'skill'), (4672, 4678, 'skill'), (5680, 5686, 'skill'), (7619, 7625, 'skill'), (9805, 9811, 'skill'), (13701, 13707, 'skill'), (21869, 21872, 'skill'), (2913, 2917, 'skill'), (2921, 2925, 'skill'), (3676, 3680, 'skill'), (3725, 3729, 'skill'), (15448, 15452, 'skill'), (15455, 15459, 'skill'), (17496, 17500, 'skill'), (18523, 18527, 'skill'), (18848, 18852, 'skill'), (19178, 19182, 'skill'), (19337, 19341, 'skill'), (19354, 19358, 'skill'), (19879, 19883, 'skill'), (20144, 20148, 'skill'), (22336, 22340, 'skill'), (23169, 23173, 'skill'), (23605, 23609, 'skill'), (23625, 23629, 'skill'), (13814, 13816, 'skill'), (17979, 17981, 'skill'), (3744, 3747, 'skill'), (13755, 13758, 'skill'), (18096, 18099, 'skill'), (18539, 18542, 'skill'), (3898, 3904, 'skill'), (4140, 4146, 'skill'), (12083, 12093, 'skill'), (3687, 3690, 'skill'), (17959, 17962, 'skill'), (18534, 18537, 'skill'), (453, 460, 'skill'), (812, 819, 'skill'), (1123, 1130, 'skill'), (1162, 1169, 'skill'), (1371, 1378, 'skill'), (4018, 4025, 'skill'), (4541, 4548, 'skill'), (4620, 4627, 'skill'), (5984, 5991, 'skill'), (6064, 6071, 'skill'), (6168, 6175, 'skill'), (6710, 6717, 'skill'), (9004, 9011, 'skill'), (9097, 9104, 'skill'), (9898, 9905, 'skill'), (9990, 9997, 'skill'), (10089, 10096, 'skill'), (10119, 10126, 'skill'), (10161, 10168, 'skill'), (10283, 10290, 'skill'), (10408, 10415, 'skill'), (10581, 10588, 'skill'), (11134, 11141, 'skill'), (11733, 11740, 'skill'), (12178, 1218 ...
# 0
# 296
# 341
# 344
# 382
# 460
# 498
# 539
# 595
# 780
# 819
# 1130
# 1169
# 1378
# 1428
# 1554
# 1631
# 1895
# 1909
# 1917
# 1927
# 1944
# 2033
# 2043
# 2152
# 2194
# 2261
# 2267
# 2267
# 2393
# 2490
# 2601
# 2608
# 2647
# 2675
# 2679
# 2686
# 2695
# 2695
# 2702
# 2708
# 2719
# 2788
# 2909
# 2913
# 2917
# 2914
# 2917
# 2921
# 2922
# 2925
# 2922
# 2925
# 2936
# 2940
# 2947
# 2953
# 2958
# 2966
# 3319
# 3664
# 3668
# 3667
# 3668
# 3671
# 3676
# 3680
# 3677
# 3680
# 3685
# 3690
# 3698
# 3698
# 3702
# 3720
# 3725
# 3726
# 3729
# 3726
# 3729
# 3742
# 3747
# 3753
# 3760
# 3783
# 3815
# 3824
# 3841
# 3860
# 3867
# 3860
# 3867
# 3867
# 3878
# 3878
# 3886
# 3896
# 3904
# 3904
# 3920
# 3937
# 3952
# 3958
# 3971
# 3971
# 3984
# 3993
# 4002
# 4002
# 4013
# 4025
# 4025
# 4057
# 4066
# 4075
# 4082
# 4100
# 4108
# 4125
# 4131
# 4138
# 4146
# 4154
# 4160
# 4173
# 4177
# 4182
# 4196
# 4272
# 4276
# 4276
# 4548
# 4606
# 4627
# 4678
# 4813
# 5074
# 5411
# 5428
# 5438
# 5544
# 5569
# 5686
# 5742
# 5991
# 6071
# 6175
# 6284
# 6600
# 6605
# 6717
# 6947
# 7014
# 7595
# 7625
# 7948
# 7966
# 7969
# 7969
# 8401
# 8510
# 8562
# 8586
# 8594
# 9011
# 9104
# 9238
# 9778
# 9897
# 9784
# 9790
# 9803
# 9811
# 9817
# 9828
# 9833
# 9836
# 9841
# 9845
# 9845
# 9855
# 9872
# 9879
# 9885
# 9892
# 9897
# 9905
# 9997
# 10096
# 10126
# 10168
# 10290
# 10415
# 10588
# 10653
# 11141
# 11328
# 11740
# 12093
# 12240
# 12130
# 12185
# 12212
# 12225
# 12248
# 12330
# 12344
# 12808
# 12901
# 13035
# 13153
# 13179
# 13515
# 13538
# 13565
# 13642
# 13678
# 13685
# 13685
# 13707
# 13713
# 13718
# 13723
# 13737
# 13731
# 13732
# 13736
# 13740
# 13753
# 13758
# 13763
# 13770
# 13775
# 13770
# 13781
# 13787
# 13807
# 13816
# 13816
# 13832
# 13828
# 13831
# 13842
# 13842
# 13851
# 13927
# 13942
# 14127
# 14277
# 14481
# 15015
# 15092
# 15217
# 15217
# 15404
# 15448
# 15449
# 15452
# 15459
# 15449
# 15452
# 15455
# 15459
# 15456
# 15459
# 15464
# 15471
# 15476
# 15471
# 15484
# 15546
# 15704
# 16253
# 16693
# 16701
# 16701
# 16729
# 17028
# 17051
# 17078
# 17430
# 17435
# 17450
# 17455
# 17458
# 17464
# 17471
# 17476
# 17471
# 17491
# 17496
# 17497
# 17500
# 17497
# 17500
# 17514
# 17523
# 17585
# 17634
# 17668
# 17745
# 17776
# 17962
# 17981
# 18022
# 18030
# 18071
# 18099
# 18135
# 18406
# 18490
# 18518
# 18523
# 18527
# 18524
# 18527
# 18532
# 18537
# 18542
# 18547
# 18554
# 18559
# 18554
# 18568
# 18577
# 18784
# 18809
# 18848
# 18852
# 18849
# 18852
# 19027
# 19104
# 19139
# 19178
# 19182
# 19179
# 19182
# 19337
# 19341
# 19338
# 19341
# 19345
# 19349
# 19348
# 19349
# 19354
# 19355
# 19358
# 19355
# 19358
# 19363
# 19369
# 19376
# 19381
# 19376
# 19390
# 19505
# 19508
# 19880
# 19883
# 19890
# 19905
# 19913
# 19925
# 19934
# 20144
# 20145
# 20148
# 20152
# 20145
# 20148
# 20151
# 20152
# 20155
# 20169
# 20174
# 20181
# 20186
# 20181
# 20195
# 20308
# 20311
# 20626
# 20638
# 20651
# 20663
# 20913
# 20917
# 20916
# 20917
# 20920
# 20926
# 20935
# 20944
# 20953
# 20966
# 20975
# 20986
# 20994
# 21044
# 21045
# 21183
# 21184
# 21252
# 21253
# 21305
# 21306
# 21409
# 21462
# 21521
# 21701
# 21721
# 21780
# 21872
# 21878
# 21882
# 21881
# 21882
# 21885
# 21899
# 21908
# 21913
# 21920
# 21920
# 21997
# 22000
# 22019
# 22090
# 22093
# 22330
# 22336
# 22337
# 22340
# 22337
# 22340
# 22348
# 22348
# 22356
# 22363
# 22356
# 22363
# 22363
# 22371
# 22500
# 23163
# 23169
# 23170
# 23173
# 23170
# 23173
# 23181
# 23183
# 23199
# 23264
# 23589
# 23599
# 23605
# 23609
# 23606
# 23609
# 23629
# 23619
# 23625
# 23626
# 23629
# 23626
# 23629
# 23637
# 23637
# 23645
# 23652
# 23645
# 23652
# 23652
# 23756
# 23763
# 23880
# 23945
# 23976
# [(1117, 1124, 'skill'), (1290, 1297, 'skill'), (2952, 2959, 'skill'), (3413, 3420, 'skill'), (5165, 5172, 'skill'), (5314, 5321, 'skill'), (1959, 1960, 'skill'), (2673, 2674, 'skill'), (4317, 4318, 'skill'), (6750, 6751, 'skill'), (9057, 9058, 'skill'), (16117, 16118, 'skill'), (1331, 1337, 'skill'), (2637, 2643, 'skill'), (1214, 1218, 'skill'), (1995, 2002, 'skill'), (1225, 1228, 'skill'), (1208, 1212, 'skill'), (1241, 1245, 'skill'), (1254, 1257, 'skill'), (1907, 1909, 'skill'), (1958, 1959, 'skill'), (2672, 2673, 'skill'), (3063, 3064, 'skill'), (3065, 3066, 'skill'), (3070, 3071, 'skill'), (5084, 5085, 'skill'), (5086, 5087, 'skill'), (6749, 6750, 'skill'), (9056, 9057, 'skill'), (9155, 9156, 'skill'), (9157, 9158, 'skill'), (10163, 10164, 'skill'), (15736, 15737, 'skill'), (15738, 15739, 'skill'), (16116, 16117, 'skill'), (17327, 17328, 'skill'), (17335, 17336, 'skill'), (1278, 1285, 'skill'), (1230, 1234, 'skill'), (9451, 9454, 'skill'), (1860, 1882, 'skill'), (2883, 2901, 'skill'), (2978, 2985, 'skill'), (2694, 2697, 'skill'), (2714, 2717, 'skill'), (9048, 9051, 'skill'), (9060, 9063, 'skill'), (1286, 1288, 'skill'), (664, 667, 'skill'), (17393, 17396, 'skill'), (1098, 1110, 'skill'), (11271, 11283, 'skill'), (17484, 17498, 'skill'), (1344, 1354, 'skill'), (1820, 1832, 'skill'), (1870, 1882, 'skill'), (3237, 3249, 'skill'), (5030, 5042, 'skill'), (7693, 7705, 'skill'), (1241, 1252, 'skill'), (1422, 1438, 'skill'), (1339, 1342, 'skill'), (5214, 5217, 'skill'), (1811, 1832, 'skill'), (1535, 1541, 'skill'), (5279, 5285, 'skill'), (2307, 2309, 'skill'), (2053, 2057, 'skill'), (2903, 2907, 'skill'), (15543, 15547, 'skill'), (15818, 15822, 'skill'), (5295, 5300, 'skill'), (12484, 12488, 'skill'), (1094, 1097, 'skill'), (2291, 2294, 'skill'), (1298, 1301, 'skill'), (2276, 2282, 'skill'), (197, 204, 'skill'), (338, 345, 'skill'), (866, 873, 'skill'), (3171, 3178, 'skill'), (3228, 3235, 'skill'), (3470, 3477, 'skill'), (3821, 3828, 'skill'), (3981, 3988, 'skill'), (4126, 4133, 'skill'), (5010, 5017, 'skill'), (5110, 5117, 'skill'), (5327, 5334, 'skill'), (5389, 5396, 'skill'), (6116, 6123, 'skill'), (6467, 6474, 'skill'), (6622, 6629, 'skill'), (6788, 6795, 'skill'), (6976, 6983, 'skill'), (7229, 7236, 'skill'), (7328, 7335, 'skill'), (7405, 7412, 'skill'), (7437, 7444, 'skill'), (8156, 8163, 'skill'), (8716, 8723, 'skill'), (8856, 8863, 'skill'), (9704, 9711, 'skill'), (10061, 10068, 'skill'), (10492, 10499, 'skill'), (10901, 10908, 'skill'), (11008, 11015, 'skill'), (12566, 12573, 'skill'), (13269, 13276, 'skill'), (14533, 14540, 'skill'), (15332, 15339, 'skill'), (16088, 16095, 'skill'), (16628, 16635, 'skill'), (2283, 2289, 'skill'), (2897, 2901, 'skill'), (2040, 2051, 'skill'), (16442, 16453, 'skill'), (17000, 17011, 'skill'), (1625, 1636, 'skill'), (5219, 5230, 'skill'), (5126, 5131, 'skill'), (6023, 6032, 'skill'), (2311, 2315, 'skill'), (214, 219, 'skill'), (358, 363, 'skill'), (2183, 2188, 'skill'), (4120, 4125, 'skill'), (4390, 4395, 'skill'), (4440, 4445, 'skill'), (4920, 4925, 'skill'), (4991, 4996, 'skill'), (6036, 6041, 'skill'), (2031, 2051, 'skill'), (16433, 16453, 'skill'), (1806, 1809, 'skill'), (8245, 8248, 'skill'), (2871, 2881, 'skill'), (1146, 1152, 'skill'), (2372, 2378, 'skill'), (2609, 2615, 'skill'), (1098, 1101, 'skill'), (1422, 1425, 'skill'), (3422, 3425, 'skill'), (14888, 14891, 'skill'), (16876, 16879, 'skill'), (2449, 2459, 'skill'), (1220, 1223, 'skill'), (1236, 1239, 'skill'), (654, 662, 'skill'), (2580, 2588, 'skill'), (8116, 8124, 'skill'), (12092, 12100, 'skill'), (2476, 2483, 'skill'), (2302, 2306, 'skill'), (1911, 1925, 'skill'), (2190, 2196, 'skill'), (2920, 2926, 'skill'), (418, 436, 'skill'), (2842, 2860, 'skill'), (11376, 11394, 'skill'), (233, 235, 'skill'), (378, 380, 'skill'), (5027, 5029, 'skill'), (9526, 9528, 'skill'), (9619, 9621, 'skill'), (9669, 9671, 'skill'), (12336, 12338, 'skill'), (13057, 13059, 'skill'), (14107, 14109, 'skill'), (14415, 14417, 'skill'), (14729, 14731, 'sk ...
# 0
# 187
# 204
# 219
# 225
# 225
# 235
# 312
# 345
# 363
# 369
# 369
# 380
# 385
# 436
# 662
# 667
# 709
# 873
# 947
# 1097
# 1101
# 1110
# 1115
# 1124
# 1134
# 1134
# 1141
# 1152
# 1212
# 1218
# 1223
# 1228
# 1234
# 1239
# 1245
# 1252
# 1257
# 1285
# 1288
# 1288
# 1297
# 1301
# 1309
# 1329
# 1337
# 1342
# 1347
# 1354
# 1354
# 1364
# 1364
# 1407
# 1425
# 1438
# 1450
# 1467
# 1518
# 1541
# 1550
# 1566
# 1622
# 1636
# 1648
# 1715
# 1789
# 1809
# 1809
# 1832
# 1824
# 1832
# 1842
# 1882
# 1874
# 1882
# 1888
# 1906
# 1909
# 1909
# 1925
# 1956
# 1959
# 1960
# 1975
# 1993
# 2002
# 2051
# 2051
# 2057
# 2071
# 2080
# 2086
# 2094
# 2102
# 2188
# 2196
# 2201
# 2231
# 2245
# 2282
# 2289
# 2294
# 2306
# 2309
# 2309
# 2315
# 2324
# 2378
# 2459
# 2483
# 2541
# 2588
# 2615
# 2634
# 2643
# 2670
# 2670
# 2673
# 2674
# 2697
# 2717
# 2720
# 2728
# 2814
# 2860
# 2881
# 2881
# 2901
# 2901
# 2907
# 2926
# 2959
# 2964
# 2985
# 3064
# 3066
# 3071
# 3178
# 3235
# 3241
# 3249
# 3255
# 3345
# 3411
# 3420
# 3425
# 3477
# 3491
# 3828
# 3988
# 4125
# 4133
# 4209
# 4232
# 4318
# 4395
# 4415
# 4445
# 4605
# 4626
# 4646
# 4727
# 4899
# 4910
# 4910
# 4925
# 4996
# 5002
# 5002
# 5017
# 5029
# 5034
# 5042
# 5085
# 5087
# 5117
# 5131
# 5160
# 5172
# 5212
# 5217
# 5230
# 5285
# 5300
# 5309
# 5321
# 5334
# 5396
# 5411
# 5609
# 5618
# 5637
# 5769
# 5795
# 6032
# 6041
# 6070
# 6123
# 6141
# 6474
# 6629
# 6750
# 6751
# 6795
# 6983
# 7236
# 7335
# 7412
# 7444
# 7566
# 7665
# 7697
# 7705
# 7894
# 8103
# 8124
# 8132
# 8154
# 8163
# 8248
# 8248
# 8274
# 8286
# 8374
# 8417
# 8723
# 8863
# 8927
# 9051
# 9057
# 9058
# 9063
# 9068
# 9114
# 9126
# 9156
# 9158
# 9237
# 9444
# 9454
# 9491
# 9514
# 9528
# 9583
# 9603
# 9618
# 9621
# 9626
# 9671
# 9711
# 9930
# 10032
# 10068
# 10164
# 10227
# 10330
# 10384
# 10455
# 10491
# 10499
# 10682
# 10872
# 10908
# 10914
# 11015
# 11283
# 11394
# 11414
# 11455
# 11524
# 11587
# 11606
# 11649
# 11779
# 11847
# 11866
# 11882
# 11923
# 12020
# 12100
# 12338
# 12430
# 12488
# 12504
# 12515
# 12538
# 12565
# 12573
# 13020
# 13059
# 13104
# 13155
# 13241
# 13276
# 13851
# 13880
# 13942
# 14109
# 14194
# 14292
# 14417
# 14461
# 14540
# 14731
# 14736
# 14759
# 14816
# 14883
# 14891
# 14917
# 14987
# 14999
# 15045
# 15230
# 15280
# 15339
# 15368
# 15461
# 15547
# 15617
# 15660
# 15715
# 15737
# 15739
# 15822
# 15932
# 16095
# 16117
# 16118
# 16237
# 16271
# 16294
# 16298
# 16336
# 16347
# 16453
# 16453
# 16607
# 16635
# 16727
# 16765
# 16801
# 16863
# 16879
# 16899
# 16963
# 16988
# 17011
# 17093
# 17101
# 17101
# 17125
# 17180
# 17223
# 17328
# 17336
# 17396
# 17498
# 17498
# 17513
# 17528
# 17561
# 17584
# 17603
# 17690
# 17739
# [(2576, 2579, 'skill'), (2627, 2630, 'skill'), (2674, 2677, 'skill'), (9934, 9937, 'skill'), (9946, 9949, 'skill'), (10035, 10038, 'skill'), (10061, 10064, 'skill'), (10637, 10640, 'skill'), (12570, 12573, 'skill'), (12614, 12617, 'skill'), (12641, 12644, 'skill'), (12674, 12677, 'skill'), (13355, 13358, 'skill'), (13448, 13451, 'skill'), (13690, 13693, 'skill'), (15371, 15374, 'skill'), (15482, 15485, 'skill'), (16652, 16655, 'skill'), (10439, 10440, 'skill'), (10448, 10449, 'skill'), (5752, 5758, 'skill'), (5838, 5844, 'skill'), (13706, 13712, 'skill'), (20877, 20883, 'skill'), (22421, 22427, 'skill'), (22763, 22769, 'skill'), (23088, 23094, 'skill'), (24023, 24029, 'skill'), (24365, 24371, 'skill'), (24560, 24566, 'skill'), (22088, 22092, 'skill'), (22987, 22991, 'skill'), (23690, 23694, 'skill'), (24459, 24463, 'skill'), (23166, 23169, 'skill'), (24638, 24641, 'skill'), (5280, 5284, 'skill'), (13092, 13096, 'skill'), (15764, 15768, 'skill'), (5728, 5731, 'skill'), (13248, 13251, 'skill'), (15808, 15811, 'skill'), (22167, 22177, 'skill'), (23769, 23779, 'skill'), (23108, 23120, 'skill'), (24580, 24592, 'skill'), (22314, 22317, 'skill'), (22521, 22524, 'skill'), (23019, 23022, 'skill'), (23916, 23919, 'skill'), (24123, 24126, 'skill'), (24491, 24494, 'skill'), (5966, 5970, 'skill'), (13695, 13699, 'skill'), (20888, 20892, 'skill'), (21091, 21095, 'skill'), (22056, 22060, 'skill'), (22547, 22551, 'skill'), (22742, 22746, 'skill'), (22981, 22985, 'skill'), (23347, 23351, 'skill'), (23658, 23662, 'skill'), (24149, 24153, 'skill'), (24344, 24348, 'skill'), (24453, 24457, 'skill'), (2581, 2584, 'skill'), (2714, 2717, 'skill'), (5950, 5953, 'skill'), (13350, 13353, 'skill'), (13679, 13682, 'skill'), (15415, 15418, 'skill'), (15507, 15510, 'skill'), (22167, 22170, 'skill'), (22659, 22662, 'skill'), (23152, 23155, 'skill'), (23769, 23772, 'skill'), (24261, 24264, 'skill'), (24624, 24627, 'skill'), (22056, 22069, 'skill'), (23658, 23671, 'skill'), (10438, 10439, 'skill'), (10447, 10448, 'skill'), (13285, 13286, 'skill'), (23031, 23032, 'skill'), (23118, 23119, 'skill'), (24503, 24504, 'skill'), (24590, 24591, 'skill'), (13718, 13735, 'skill'), (10451, 10461, 'skill'), (23128, 23138, 'skill'), (24600, 24610, 'skill'), (5050, 5061, 'skill'), (1839, 1843, 'skill'), (5944, 5948, 'skill'), (10432, 10436, 'skill'), (22515, 22519, 'skill'), (23122, 23126, 'skill'), (24117, 24121, 'skill'), (24594, 24598, 'skill'), (10442, 10449, 'skill'), (4932, 4937, 'skill'), (4897, 4904, 'skill'), (22945, 22952, 'skill'), (22676, 22679, 'skill'), (23156, 23159, 'skill'), (24278, 24281, 'skill'), (24628, 24631, 'skill'), (5630, 5637, 'skill'), (5706, 5709, 'skill'), (13782, 13788, 'skill'), (19152, 19155, 'skill'), (2549, 2561, 'skill'), (4090, 4102, 'skill'), (12557, 12569, 'skill'), (761, 773, 'skill'), (1068, 1080, 'skill'), (5135, 5147, 'skill'), (14490, 14502, 'skill'), (16712, 16724, 'skill'), (17480, 17492, 'skill'), (19229, 19245, 'skill'), (13695, 13702, 'skill'), (10490, 10500, 'skill'), (10539, 10549, 'skill'), (4897, 4907, 'skill'), (10497, 10500, 'skill'), (10546, 10549, 'skill'), (20643, 20653, 'skill'), (2812, 2820, 'skill'), (23108, 23116, 'skill'), (24580, 24588, 'skill'), (23140, 23145, 'skill'), (24612, 24617, 'skill'), (1968, 1973, 'skill'), (4959, 4964, 'skill'), (8235, 8240, 'skill'), (10350, 10355, 'skill'), (13668, 13673, 'skill'), (15116, 15121, 'skill'), (16625, 16630, 'skill'), (18495, 18500, 'skill'), (19187, 19192, 'skill'), (13259, 13283, 'skill'), (13737, 13761, 'skill'), (13763, 13770, 'skill'), (23099, 23106, 'skill'), (24571, 24578, 'skill'), (22547, 22558, 'skill'), (24149, 24160, 'skill'), (13772, 13781, 'skill'), (5831, 5836, 'skill'), (16686, 16691, 'skill'), (4979, 4992, 'skill'), (4245, 4248, 'skill'), (1328, 1331, 'skill'), (20111, 20114, 'skill'), (1890, 1893, 'skill'), (8149, 8152, 'skill'), (13675, 13678, 'skill'), (16726, 16729, 'skill'), (19217, 19220, 'skill'), (22971, 22974, 'skill'), (23045, 23048, 'skill') ...
# 0
# 11
# 193
# 568
# 582
# 589
# 596
# 606
# 616
# 616
# 773
# 1080
# 1301
# 1326
# 1331
# 1342
# 1579
# 1810
# 1825
# 1843
# 1862
# 1893
# 1902
# 1973
# 1973
# 2283
# 2301
# 2321
# 2333
# 2348
# 2360
# 2374
# 2428
# 2452
# 2471
# 2480
# 2492
# 2492
# 2500
# 2500
# 2547
# 2552
# 2561
# 2566
# 2575
# 2579
# 2584
# 2593
# 2610
# 2630
# 2659
# 2659
# 2677
# 2697
# 2717
# 2746
# 2820
# 3487
# 3504
# 3534
# 3671
# 3769
# 3874
# 3889
# 3889
# 4093
# 4102
# 4134
# 4142
# 4224
# 4248
# 4305
# 4344
# 4383
# 4422
# 4447
# 4518
# 4616
# 4633
# 4904
# 4907
# 4913
# 4907
# 4931
# 4937
# 4964
# 4964
# 4992
# 4992
# 4999
# 5024
# 5035
# 5041
# 5055
# 5061
# 5061
# 5068
# 5072
# 5078
# 5147
# 5184
# 5202
# 5222
# 5251
# 5284
# 5290
# 5358
# 5387
# 5387
# 5402
# 5402
# 5409
# 5440
# 5447
# 5455
# 5455
# 5466
# 5478
# 5490
# 5500
# 5555
# 5555
# 5568
# 5578
# 5588
# 5594
# 5600
# 5609
# 5615
# 5618
# 5618
# 5628
# 5637
# 5667
# 5675
# 5687
# 5687
# 5694
# 5704
# 5704
# 5709
# 5731
# 5737
# 5750
# 5758
# 5776
# 5802
# 5810
# 5810
# 5817
# 5836
# 5844
# 5855
# 5855
# 5910
# 5917
# 5948
# 5953
# 5958
# 5970
# 6615
# 6813
# 6817
# 7279
# 7517
# 7775
# 7889
# 8110
# 8152
# 8175
# 8240
# 8240
# 8409
# 9000
# 9056
# 9085
# 9097
# 9109
# 9209
# 9214
# 9265
# 9300
# 9319
# 9342
# 9372
# 9443
# 9459
# 9551
# 9579
# 9626
# 9767
# 9937
# 9949
# 10038
# 10064
# 10151
# 10163
# 10163
# 10178
# 10345
# 10355
# 10360
# 10355
# 10366
# 10378
# 10392
# 10392
# 10392
# 10402
# 10402
# 10417
# 10417
# 10430
# 10436
# 10440
# 10439
# 10440
# 10445
# 10447
# 10449
# 10448
# 10449
# 10461
# 10467
# 10476
# 10488
# 10488
# 10500
# 10500
# 10505
# 10523
# 10513
# 10537
# 10537
# 10549
# 10568
# 10549
# 10577
# 10592
# 10615
# 10615
# 10622
# 10628
# 10648
# 10640
# 10659
# 10659
# 10671
# 10683
# 10683
# 10705
# 10720
# 10946
# 10969
# 11524
# 11637
# 12004
# 12158
# 12173
# 12191
# 12284
# 12382
# 12512
# 12555
# 12560
# 12569
# 12573
# 12581
# 12595
# 12617
# 12640
# 12644
# 12644
# 12655
# 12663
# 12677
# 12685
# 12824
# 13096
# 13105
# 13251
# 13270
# 13283
# 13286
# 13330
# 13335
# 13342
# 13348
# 13353
# 13358
# 13441
# 13451
# 13460
# 13496
# 13496
# 13552
# 13572
# 13596
# 13603
# 13622
# 13615
# 13634
# 13634
# 13645
# 13651
# 13663
# 13663
# 13673
# 13673
# 13678
# 13682
# 13688
# 13693
# 13699
# 13702
# 13704
# 13712
# 13716
# 13716
# 13735
# 13735
# 13748
# 13761
# 13770
# 13781
# 13788
# 13809
# 13982
# 13986
# 14030
# 14295
# 14502
# 14538
# 14592
# 14817
# 14888
# 15019
# 15037
# 15077
# 15121
# 15121
# 15170
# 15170
# 15219
# 15251
# 15265
# 15306
# 15311
# 15332
# 15355
# 15374
# 15394
# 15418
# 15447
# 15465
# 15485
# 15493
# 15502
# 15510
# 15731
# 15768
# 15780
# 15801
# 15811
# 15833
# 16013
# 16338
# 16346
# 16354
# 16380
# 16437
# 16552
# 16563
# 16572
# 16572
# 16572
# 16582
# 16582
# 16597
# 16597
# 16607
# 16620
# 16630
# 16630
# 16642
# 16642
# 16650
# 16650
# 16655
# 16667
# 16684
# 16691
# 16698
# 16698
# 16710
# 16724
# 16729
# 16734
# 16742
# 16742
# 16989
# 16993
# 17026
# 17175
# 17492
# 17579
# 17694
# 17805
# 17926
# 17953
# 18185
# 18239
# 18326
# 18419
# 18500
# 18500
# 18623
# 18739
# 18744
# 18875
# 18898
# 19096
# 19155
# 19160
# 19167
# 19173
# 19173
# 19182
# 19192
# 19192
# 19204
# 19204
# 19215
# 19220
# 19227
# 19245
# 19263
# 19268
# 19274
# 19282
# 19291
# 19299
# 19311
# 19311
# 19322
# 19328
# 19337
# 19337
# 19337
# 19347
# 19347
# 19359
# 19372
# 19372
# 19378
# 19387
# 19394
# 19406
# 19612
# 19633
# 20109
# 20114
# 20122
# 20183
# 20309
# 20588
# 20596
# 20646
# 20653
# 20653
# 20668
# 20690
# 20702
# 20717
# 20742
# 20742
# 20864
# 20875
# 20883
# 20892
# 21095
# 21238
# 21242
# 21415
# 21477
# 21517
# 21633
# 21781
# 21873
# 22000
# 22060
# 22069
# 22069
# 22092
# 22126
# 22139
# 22149
# 22170
# 22177
# 22237
# 22305
# 22317
# 22354
# 22427
# 22436
# 22447
# 22508
# 22519
# 22524
# 22531
# 22551
# 22558
# 22622
# 22662
# 22679
# 22717
# 22746
# 22752
# 22762
# 22769
# 22778
# 22813
# 22852
# 22898
# 22909
# 22919
# 22919
# 22930
# 22930
# 22943
# 22952
# 22957
# 22969
# 22974
# 22985
# 22985
# 22991
# 23001
# 23017
# 23022
# 23033
# 23032
# 23038
# 23043
# 23048
# 23067
# 23071
# 23078
# 23086
# 23094
# 23097
# 23106
# 23116
# 23120
# 23119
# 23126
# 23138
# 23145
# 23150
# 23155
# 23159
# 23159
# 23164
# 23169
# 23351
# 23495
# 23499
# 23662
# 23671
# 23671
# 23694
# 23728
# 23741
# 23751
# 23772
# 23779
# 23839
# 23907
# 23919
# 23956
# 24029
# 24038
# 24049
# 24110
# 24121
# 24126
# 24133
# 24153
# 24160
# 24224
# 24264
# 24281
# 24319
# 24348
# 24354
# 24364
# 24371
# 24380
# 24415
# 24457
# 24457
# 24463
# 24473
# 24489
# 24494
# 24505
# 24504
# 24510
# 24515
# 24520
# 24539
# 24543
# 24550
# 24558
# 24566
# 24569
# 24578
# 24588
# 24592
# 24591
# 24598
# 24610
# 24617
# 24622
# 24627
# 24631
# 24631
# 24636
# 24641
# 24673
# [(200, 206, 'skill'), (241, 247, 'skill'), (299, 305, 'skill'), (2785, 2791, 'skill'), (2917, 2923, 'skill'), (5031, 5037, 'skill'), (5618, 5624, 'skill'), (2827, 2828, 'skill'), (3499, 3509, 'skill'), (2886, 2896, 'skill'), (61, 62, 'skill'), (199, 200, 'skill'), (319, 320, 'skill'), (321, 322, 'skill'), (2961, 2962, 'skill'), (5640, 5641, 'skill'), (5642, 5643, 'skill'), (5648, 5649, 'skill'), (5650, 5651, 'skill'), (1357, 1363, 'skill'), (6410, 6416, 'skill'), (2664, 2671, 'skill'), (2832, 2839, 'skill'), (2886, 2893, 'skill'), (9044, 9047, 'skill'), (9166, 9169, 'skill'), (207, 210, 'skill'), (4977, 4980, 'skill'), (4700, 4712, 'skill'), (612, 620, 'skill'), (637, 653, 'skill'), (3189, 3205, 'skill'), (3386, 3402, 'skill'), (8829, 8832, 'skill'), (3320, 3325, 'skill'), (3035, 3038, 'skill'), (3100, 3103, 'skill'), (3169, 3172, 'skill'), (12136, 12140, 'skill'), (2946, 2952, 'skill'), (3710, 3720, 'skill'), (254, 257, 'skill'), (327, 330, 'skill'), (5044, 5047, 'skill'), (5655, 5658, 'skill'), (192, 199, 'skill'), (2301, 2308, 'skill'), (3303, 3310, 'skill'), (3330, 3337, 'skill'), (7090, 7097, 'skill'), (7407, 7414, 'skill'), (7624, 7631, 'skill'), (7793, 7800, 'skill'), (8362, 8369, 'skill'), (9460, 9467, 'skill'), (10195, 10202, 'skill'), (10318, 10325, 'skill'), (10453, 10460, 'skill'), (11161, 11168, 'skill'), (11541, 11548, 'skill'), (3317, 3325, 'skill'), (2767, 2772, 'skill'), (8760, 8765, 'skill'), (2970, 2973, 'skill'), (2373, 2378, 'skill'), (2992, 2996, 'skill'), (3280, 3291, 'skill'), (2950, 2959, 'skill'), (2059, 2077, 'skill'), (2352, 2370, 'skill'), (6945, 6963, 'skill'), (558, 560, 'skill'), (6727, 6729, 'skill'), (3490, 3497, 'skill'), (3259, 3275, 'skill'), (2936, 2941, 'skill'), (2796, 2799, 'skill'), (2928, 2931, 'skill'), (2965, 2968, 'skill'), (7537, 7543, 'skill'), (3426, 3436, 'skill'), (9595, 9605, 'skill'), (11296, 11306, 'skill'), (3511, 3516, 'skill'), (7290, 7295, 'skill'), (2755, 2765, 'skill'), (3518, 3522, 'skill'), (2793, 2799, 'skill'), (2925, 2931, 'skill'), (2870, 2879, 'skill'), (579, 582, 'skill'), (3477, 3488, 'skill'), (3464, 3475, 'skill'), (4755, 4762, 'skill'), (8904, 8908, 'skill'), (2946, 2963, 'skill'), (299, 316, 'skill'), (2394, 2399, 'skill'), (2866, 2879, 'skill'), (2950, 2952, 'skill'), (594, 608, 'skill'), (562, 565, 'skill'), (6731, 6734, 'skill'), (62, 65, 'skill'), (354, 356, 'skill'), (3365, 3368, 'skill'), (11652, 11655, 'skill'), (2946, 2959, 'skill'), (3430, 3436, 'skill'), (7242, 7248, 'skill'), (9599, 9605, 'skill'), (11300, 11306, 'skill'), (77, 85, 'experience'), (2, 9, 'person'), (8379, 8386, 'city')]
# 0
# 9
# 62
# 65
# 85
# 199
# 200
# 206
# 210
# 247
# 257
# 305
# 316
# 320
# 322
# 330
# 356
# 560
# 565
# 582
# 608
# 620
# 653
# 1363
# 2077
# 2308
# 2370
# 2378
# 2399
# 2671
# 2765
# 2772
# 2791
# 2799
# 2799
# 2828
# 2839
# 2879
# 2879
# 2893
# 2896
# 2923
# 2931
# 2931
# 2941
# 2952
# 2959
# 2963
# 2952
# 2959
# 2962
# 2968
# 2973
# 2996
# 3038
# 3103
# 3172
# 3205
# 3275
# 3291
# 3310
# 3325
# 3325
# 3337
# 3368
# 3402
# 3436
# 3436
# 3475
# 3488
# 3497
# 3509
# 3516
# 3522
# 3720
# 4712
# 4762
# 4980
# 5037
# 5047
# 5624
# 5641
# 5643
# 5649
# 5651
# 5658
# 6416
# 6729
# 6734
# 6963
# 7097
# 7248
# 7295
# 7414
# 7543
# 7631
# 7800
# 8369
# 8386
# 8765
# 8832
# 8908
# 9047
# 9169
# 9467
# 9605
# 9605
# 10202
# 10325
# 10460
# 11168
# 11306
# 11306
# 11548
# 11655
# [(5724, 5727, 'skill'), (3756, 3757, 'skill'), (8163, 8164, 'skill'), (8224, 8225, 'skill'), (8239, 8240, 'skill'), (9583, 9584, 'skill'), (10772, 10773, 'skill'), (10804, 10805, 'skill'), (10869, 10870, 'skill'), (15361, 15362, 'skill'), (18183, 18184, 'skill'), (18793, 18794, 'skill'), (2328, 2334, 'skill'), (2785, 2791, 'skill'), (3339, 3345, 'skill'), (3374, 3380, 'skill'), (3853, 3859, 'skill'), (10244, 10250, 'skill'), (10877, 10883, 'skill'), (13806, 13812, 'skill'), (16922, 16928, 'skill'), (17833, 17839, 'skill'), (18828, 18834, 'skill'), (209, 213, 'skill'), (2053, 2057, 'skill'), (2260, 2264, 'skill'), (3117, 3121, 'skill'), (3515, 3519, 'skill'), (8725, 8729, 'skill'), (10693, 10697, 'skill'), (3584, 3590, 'skill'), (656, 663, 'skill'), (4314, 4321, 'skill'), (6399, 6406, 'skill'), (7540, 7547, 'skill'), (8345, 8352, 'skill'), (13877, 13884, 'skill'), (16557, 16564, 'skill'), (12419, 12422, 'skill'), (7967, 7973, 'skill'), (8146, 8152, 'skill'), (12424, 12428, 'skill'), (17062, 17076, 'skill'), (5912, 5918, 'skill'), (2310, 2320, 'skill'), (7880, 7890, 'skill'), (5502, 5506, 'skill'), (6127, 6131, 'skill'), (2674, 2687, 'skill'), (11101, 11108, 'skill'), (18280, 18287, 'skill'), (4301, 4306, 'skill'), (7409, 7414, 'skill'), (849, 859, 'skill'), (19826, 19836, 'skill'), (2076, 2079, 'skill'), (3690, 3693, 'skill'), (8308, 8311, 'skill'), (8977, 8980, 'skill'), (9814, 9817, 'skill'), (9944, 9947, 'skill'), (10849, 10852, 'skill'), (16166, 16169, 'skill'), (5309, 5320, 'skill'), (9533, 9544, 'skill'), (9995, 10006, 'skill'), (15306, 15317, 'skill'), (5309, 5329, 'skill'), (9533, 9553, 'skill'), (9995, 10015, 'skill'), (15306, 15326, 'skill'), (203, 207, 'skill'), (294, 298, 'skill'), (573, 577, 'skill'), (2254, 2258, 'skill'), (2360, 2364, 'skill'), (3356, 3360, 'skill'), (3643, 3647, 'skill'), (4069, 4073, 'skill'), (4833, 4837, 'skill'), (4860, 4864, 'skill'), (7967, 7971, 'skill'), (8014, 8018, 'skill'), (8146, 8150, 'skill'), (8487, 8491, 'skill'), (10757, 10761, 'skill'), (11013, 11017, 'skill'), (11465, 11469, 'skill'), (11904, 11908, 'skill'), (13775, 13779, 'skill'), (14055, 14059, 'skill'), (15887, 15891, 'skill'), (16882, 16886, 'skill'), (16943, 16947, 'skill'), (17166, 17170, 'skill'), (17794, 17798, 'skill'), (17883, 17887, 'skill'), (17944, 17948, 'skill'), (18170, 18174, 'skill'), (18378, 18382, 'skill'), (18800, 18804, 'skill'), (1939, 1942, 'skill'), (2097, 2100, 'skill'), (2180, 2183, 'skill'), (3152, 3155, 'skill'), (3695, 3698, 'skill'), (4138, 4141, 'skill'), (8185, 8188, 'skill'), (10807, 10810, 'skill'), (12402, 12405, 'skill'), (13790, 13793, 'skill'), (16888, 16891, 'skill'), (18806, 18809, 'skill'), (45, 46, 'skill'), (3654, 3655, 'skill'), (3755, 3756, 'skill'), (3757, 3758, 'skill'), (3800, 3801, 'skill'), (3802, 3803, 'skill'), (3984, 3985, 'skill'), (8162, 8163, 'skill'), (8164, 8165, 'skill'), (8179, 8180, 'skill'), (8181, 8182, 'skill'), (8223, 8224, 'skill'), (8228, 8229, 'skill'), (8238, 8239, 'skill'), (9568, 9569, 'skill'), (9582, 9583, 'skill'), (10803, 10804, 'skill'), (10868, 10869, 'skill'), (10873, 10874, 'skill'), (11106, 11107, 'skill'), (13786, 13787, 'skill'), (13844, 13845, 'skill'), (13848, 13849, 'skill'), (15341, 15342, 'skill'), (15360, 15361, 'skill'), (16877, 16878, 'skill'), (17010, 17011, 'skill'), (17014, 17015, 'skill'), (17234, 17235, 'skill'), (17875, 17876, 'skill'), (17879, 17880, 'skill'), (18182, 18183, 'skill'), (18285, 18286, 'skill'), (18792, 18793, 'skill'), (18796, 18797, 'skill'), (18892, 18893, 'skill'), (18896, 18897, 'skill'), (19797, 19798, 'skill'), (7978, 7985, 'skill'), (8070, 8077, 'skill'), (8354, 8361, 'skill'), (2360, 2379, 'skill'), (2323, 2326, 'skill'), (2185, 2195, 'skill'), (4041, 4051, 'skill'), (8296, 8306, 'skill'), (8957, 8967, 'skill'), (9828, 9838, 'skill'), (10156, 10166, 'skill'), (10829, 10839, 'skill'), (17018, 17028, 'skill'), (8197, 8202, 'skill'), (9637, 9642, 'skill'), (15753, 15758, 'skill'), (4058, 4062, 'skill'), (9803 ...
# 0
# 12
# 46
# 49
# 75
# 145
# 207
# 207
# 213
# 298
# 323
# 337
# 369
# 453
# 464
# 577
# 613
# 637
# 663
# 690
# 698
# 698
# 847
# 856
# 859
# 1074
# 1172
# 1265
# 1330
# 1364
# 1647
# 1682
# 1687
# 1705
# 1714
# 1767
# 1894
# 1921
# 1934
# 1925
# 1934
# 1942
# 1951
# 2018
# 2057
# 2079
# 2089
# 2095
# 2100
# 2109
# 2122
# 2113
# 2122
# 2154
# 2172
# 2178
# 2183
# 2195
# 2211
# 2228
# 2258
# 2264
# 2272
# 2277
# 2286
# 2292
# 2298
# 2308
# 2316
# 2320
# 2320
# 2326
# 2334
# 2342
# 2364
# 2379
# 2379
# 2444
# 2471
# 2615
# 2628
# 2637
# 2680
# 2687
# 2687
# 2791
# 2799
# 2846
# 2890
# 2898
# 2898
# 2932
# 2939
# 2969
# 3063
# 3065
# 3121
# 3155
# 3159
# 3159
# 3345
# 3360
# 3380
# 3459
# 3519
# 3535
# 3535
# 3563
# 3590
# 3616
# 3647
# 3652
# 3656
# 3656
# 3655
# 3662
# 3667
# 3672
# 3680
# 3688
# 3693
# 3698
# 3704
# 3715
# 3719
# 3722
# 3753
# 3755
# 3757
# 3759
# 3757
# 3756
# 3757
# 3758
# 3798
# 3800
# 3802
# 3804
# 3801
# 3803
# 3810
# 3818
# 3818
# 3826
# 3841
# 3859
# 3864
# 3874
# 3885
# 3905
# 3947
# 3954
# 3947
# 3954
# 3954
# 3974
# 3974
# 3981
# 3985
# 4005
# 4015
# 4037
# 4039
# 4051
# 4056
# 4062
# 4067
# 4073
# 4079
# 4079
# 4120
# 4132
# 4135
# 4141
# 4147
# 4176
# 4180
# 4180
# 4191
# 4229
# 4257
# 4272
# 4272
# 4284
# 4306
# 4312
# 4321
# 4353
# 4451
# 4520
# 4545
# 4626
# 4639
# 4655
# 4663
# 4684
# 4705
# 4710
# 4735
# 4744
# 4754
# 4761
# 4837
# 4864
# 5316
# 5320
# 5329
# 5320
# 5329
# 5357
# 5483
# 5497
# 5506
# 5565
# 5574
# 5587
# 5595
# 5595
# 5619
# 5643
# 5652
# 5727
# 5742
# 5806
# 5815
# 5899
# 5918
# 5929
# 6076
# 6091
# 6100
# 6122
# 6122
# 6131
# 6141
# 6146
# 6160
# 6160
# 6164
# 6164
# 6189
# 6198
# 6203
# 6230
# 6235
# 6251
# 6263
# 6292
# 6297
# 6342
# 6348
# 6348
# 6352
# 6372
# 6406
# 6468
# 6472
# 6503
# 6539
# 6549
# 6558
# 6569
# 6691
# 6700
# 6711
# 6767
# 6785
# 6788
# 6788
# 6799
# 7024
# 7084
# 7096
# 7100
# 7100
# 7151
# 7248
# 7252
# 7277
# 7285
# 7298
# 7364
# 7400
# 7404
# 7404
# 7414
# 7433
# 7438
# 7483
# 7489
# 7489
# 7493
# 7513
# 7547
# 7554
# 7685
# 7784
# 7788
# 7808
# 7815
# 7815
# 7886
# 7890
# 7890
# 7900
# 7918
# 7925
# 7925
# 7971
# 7973
# 7985
# 7988
# 7990
# 7988
# 7999
# 8018
# 8055
# 8064
# 8077
# 8080
# 8082
# 8080
# 8085
# 8150
# 8152
# 8160
# 8162
# 8164
# 8166
# 8164
# 8163
# 8164
# 8165
# 8177
# 8179
# 8181
# 8183
# 8180
# 8182
# 8188
# 8195
# 8202
# 8207
# 8214
# 8230
# 8224
# 8225
# 8229
# 8236
# 8240
# 8239
# 8240
# 8247
# 8253
# 8256
# 8256
# 8273
# 8273
# 8286
# 8286
# 8294
# 8306
# 8311
# 8326
# 8333
# 8326
# 8333
# 8333
# 8343
# 8352
# 8361
# 8364
# 8366
# 8364
# 8371
# 8376
# 8391
# 8491
# 8729
# 8739
# 8816
# 8865
# 8869
# 8877
# 8949
# 8967
# 8975
# 8980
# 8987
# 8995
# 9202
# 9506
# 9514
# 9514
# 9540
# 9544
# 9553
# 9544
# 9553
# 9566
# 9569
# 9580
# 9584
# 9583
# 9584
# 9642
# 9695
# 9778
# 9784
# 9789
# 9793
# 9793
# 9807
# 9812
# 9817
# 9826
# 9838
# 9849
# 9849
# 9898
# 9907
# 9939
# 9947
# 9955
# 9968
# 9988
# 9990
# 9994
# 9994
# 10002
# 10006
# 10015
# 10006
# 10015
# 10028
# 10054
# 10071
# 10110
# 10132
# 10153
# 10166
# 10172
# 10180
# 10218
# 10226
# 10250
# 10260
# 10280
# 10285
# 10330
# 10336
# 10336
# 10340
# 10360
# 10697
# 10761
# 10769
# 10771
# 10773
# 10781
# 10783
# 10787
# 10787
# 10795
# 10805
# 10801
# 10805
# 10804
# 10805
# 10810
# 10817
# 10822
# 10827
# 10839
# 10847
# 10852
# 10859
# 10875
# 10869
# 10870
# 10874
# 10883
# 11017
# 11104
# 11108
# 11107
# 11181
# 11200
# 11227
# 11368
# 11469
# 11469
# 11575
# 11762
# 11770
# 11770
# 11858
# 11908
# 11908
# 12025
# 12029
# 12186
# 12214
# 12405
# 12422
# 12428
# 12434
# 12447
# 12451
# 12460
# 12470
# 12492
# 12497
# 12508
# 12545
# 12551
# 12551
# 12555
# 12575
# 12606
# 12689
# 12717
# 12767
# 12817
# 12829
# 12900
# 12938
# 12943
# 12972
# 13140
# 13156
# 13164
# 13188
# 13210
# 13223
# 13240
# 13288
# 13330
# 13765
# 13773
# 13773
# 13779
# 13784
# 13788
# 13787
# 13793
# 13798
# 13804
# 13812
# 13816
# 13821
# 13830
# 13833
# 13836
# 13850
# 13845
# 13849
# 13856
# 13861
# 13868
# 13875
# 13884
# 13894
# 13906
# 13913
# 13923
# 13929
# 13935
# 14059
# 14297
# 14432
# 14498
# 14621
# 14732
# 14743
# 14826
# 14842
# 14939
# 14947
# 14947
# 14983
# 15008
# 15042
# 15042
# 15051
# 15064
# 15055
# 15064
# 15119
# 15122
# 15139
# 15177
# 15224
# 15231
# 15240
# 15292
# 15313
# 15317
# 15326
# 15317
# 15326
# 15339
# 15342
# 15353
# 15358
# 15361
# 15362
# 15516
# 15548
# 15758
# 15812
# 15817
# 15880
# 15891
# 15897
# 15897
# 15927
# 15995
# 15998
# 16016
# 16024
# 16046
# 16105
# 16113
# 16113
# 16141
# 16169
# 16180
# 16209
# 16224
# 16299
# 16322
# 16345
# 16366
# 16372
# 16372
# 16392
# 16472
# 16477
# 16489
# 16503
# 16542
# 16564
# 16571
# 16582
# 16630
# 16851
# 16859
# 16859
# 16867
# 16875
# 16878
# 16886
# 16891
# 16897
# 16902
# 16907
# 16913
# 16919
# 16928
# 16932
# 16936
# 16932
# 16941
# 16947
# 16953
# 16953
# 16960
# 16987
# 16987
# 16987
# 16996
# 16999
# 17002
# 17016
# 17011
# 17015
# 17028
# 17033
# 17039
# 17044
# 17051
# 17060
# 17066
# 17076
# 17076
# 17089
# 17170
# 17204
# 17235
# 17295
# 17390
# 17428
# 17531
# 17740
# 17798
# 17804
# 17804
# 17813
# 17829
# 17839
# 17843
# 17847
# 17843
# 17852
# 17861
# 17864
# 17867
# 17881
# 17876
# 17880
# 17887
# 17893
# 17893
# 17948
# 18016
# 18115
# 18137
# 18156
# 18156
# 18156
# 18174
# 18180
# 18183
# 18184
# 18206
# 18217
# 18239
# 18253
# 18283
# 18287
# 18286
# 18340
# 18382
# 18489
# 18497
# 18497
# 18585
# 18604
# 18609
# 18654
# 18660
# 18660
# 18664
# 18684
# 18716
# 18726
# 18748
# 18753
# 18777
# 18785
# 18785
# 18790
# 18794
# 18798
# 18793
# 18794
# 18797
# 18804
# 18809
# 18814
# 18819
# 18825
# 18834
# 18838
# 18838
# 18843
# 18850
# 18869
# 18869
# 18869
# 18878
# 18881
# 18884
# 18898
# 18893
# 18897
# 18905
# 18912
# 19307
# 19331
# 19591
# 19595
# 19657
# 19697
# 19795
# 19798
# 19833
# 19836
# 19905
# 20029
# 20061
# 20072
# 20082
# 20292
# 20402
# 20418
# ...
# 2600
# 2615
# 2626
# 2619
# 2645
# 2649
# 2692
# 2737
# 2777
# 2783
# 2791
# 2811
# 2814
# 2814
# 2883
# 2899
# 2918
# 2942
# 3352
# 3405
# 4183
# 4202
# 4295
# 4307
# 4353
# 4431
# 4484
# 4504
# 4659
# 4793
# 4832
# 4892
# 4925
# 4933
# 4994
# 5006
# 4998
# 5006
# 5043
# 5131
# 5141
# 5192
# 5207
# 5214
# 5336
# 5339
# 5339
# 5368
# 5377
# 5385
# 5490
# 5686
# 5698
# 5709
# 5762
# 5767
# 5779
# 5908
# 5919
# 5957
# 6015
# 6027
# 6081
# 6144
# 6154
# 6160
# 6165
# 6173
# 6184
# 6190
# 6199
# 6202
# 6208
# 6202
# 6221
# 6229
# 6239
# 6245
# 6248
# 6248
# 6256
# 6266
# 6273
# 6296
# 6378
# 6729
# 6983
# 7095
# 7547
# 7568
# 7578
# 7584
# 7592
# 7603
# 7620
# 7625
# 7637
# 7723
# 7778
# 7788
# 7796
# 7806
# 7815
# 7858
# 7868
# 7872
# 7899
# 7914
# 7933
# 8010
# 8002
# 8010
# 8081
# 8106
# 8115
# 8135
# 8161
# 8201
# 8209
# 8254
# 8271
# 8394
# 8407
# 8426
# 8451
# 8438
# 8442
# 8451
# 8442
# 8451
# 8459
# 8476
# 8485
# 8493
# 8503
# 8506
# 8506
# 8549
# 8555
# 8584
# 8607
# 8612
# 8612
# 8621
# 8632
# 8635
# 8635
# 8643
# 8683
# 8697
# 8708
# 8732
# 8740
# 8743
# 8743
# 8762
# 8770
# 8800
# 8809
# 8862
# 8865
# 8865
# 8894
# 8903
# 8911
# 8933
# 8951
# 9024
# 9121
# 9134
# 9145
# 9175
# 9213
# 9218
# 9230
# 9287
# 9313
# 9320
# 9342
# 9361
# 9371
# 9388
# 9453
# 9463
# 9472
# 9482
# 9488
# 9491
# 9491
# 9498
# 9511
# 9519
# 9528
# 9536
# 9545
# 9552
# 9558
# 9567
# 9572
# 9579
# 9579
# 9587
# 9599
# 9604
# 9610
# 9618
# 9628
# 9633
# 9648
# 9676
# 9752
# 9945
# 10007
# 10118
# 10275
# 10638
# 10663
# 10675
# 10718
# 10784
# 10845
# 10850
# 10862
# 10935
# 11181
# 11202
# 11212
# 11218
# 11225
# 11234
# 11276
# 11339
# 11352
# 11362
# 11390
# 11413
# 11418
# 11418
# 11427
# 11438
# 11441
# 11441
# 11449
# 11481
# 11531
# 11541
# 11632
# 11674
# 11720
# 11728
# 11735
# 11741
# 11754
# 11760
# 11761
# 11764
# 11761
# 11764
# 11772
# 11778
# 11789
# 11795
# 11804
# 11807
# 11813
# 11807
# 11818
# 11828
# 11833
# 11837
# 12541
# 12566
# 12595
# 12647
# 12691
# 12740
# 12944
# 12968
# 12989
# 13110
# 13352
# 13354
# 13370
# 13379
# 13386
# 13392
# 13400
# 13405
# 13415
# 13421
# 13429
# 13437
# 13441
# 13467
# 13777
# 13996
# 14008
# 14022
# 14038
# 14101
# 14191
# 14255
# 14296
# 14369
# 14464
# 14513
# 14537
# 14545
# 14566
# 14586
# 14697
# 14727
# 14735
# 14763
# 14807
# 14944
# 15145
# 15150
# 15157
# 15162
# 15157
# 15180
# 15175
# 15180
# 15189
# 15204
# 15200
# 15204
# 15203
# 15213
# 15228
# 15230
# 15228
# 15240
# 15249
# 15253
# 16104
# 16133
# 16145
# 16245
# 16294
# 16320
# 16409
# 16465
# 16470
# 16516
# 16540
# 16627
# 16683
# 16691
# 16782
# 16792
# 16798
# 16804
# 16808
# 16817
# 16825
# 16917
# 16922
# 16928
# 16934
# 16942
# 16990
# 17005
# 17011
# 17025
# 17042
# 17051
# 17062
# 17065
# 17065
# 17076
# 17084
# 17097
# 17105
# 17115
# 17125
# 17153
# 17169
# 17181
# 17182
# 17189
# 17199
# 17223
# 17215
# 17223
# 17256
# 17265
# 17273
# 17308
# 17314
# 17319
# 17327
# 17327
# 17331
# 17340
# 17344
# 17350
# 17356
# 17359
# 17359
# 17363
# 17381
# 17390
# 17393
# 17393
# 17399
# 17404
# 17410
# 17417
# 17422
# 17440
# 17448
# 17454
# 17459
# 17465
# 17472
# 17478
# 17500
# 17507
# 17513
# 17525
# 17539
# 17564
# 17569
# 17576
# 17582
# 17591
# 17594
# 17600
# 17594
# 17631
# 17635
# 17643
# 17650
# 17655
# 17643
# 17650
# 17655
# 17650
# 17695
# 17734
# 17767
# 17785
# 17802
# 17811
# 17837
# 17841
# 17840
# 17844
# 17849
# 17848
# 17849
# 17859
# 17862
# 17883
# 17889
# 17889
# 17900
# 17916
# 17924
# 17927
# 17941
# 17946
# 17951
# 17968
# [(13028, 13034, 'skill'), (14526, 14532, 'skill'), (14715, 14721, 'skill'), (14726, 14732, 'skill'), (14738, 14744, 'skill'), (1788, 1794, 'skill'), (2386, 2389, 'skill'), (5682, 5692, 'skill'), (5928, 5938, 'skill'), (9248, 9258, 'skill'), (9288, 9294, 'skill'), (14709, 14713, 'skill'), (5705, 5711, 'skill'), (35, 36, 'skill'), (2341, 2342, 'skill'), (5692, 5693, 'skill'), (8672, 8673, 'skill'), (8674, 8675, 'skill'), (8690, 8691, 'skill'), (9258, 9259, 'skill'), (12673, 12700, 'skill'), (2861, 2872, 'skill'), (9362, 9365, 'skill'), (12832, 12835, 'skill'), (14669, 14681, 'skill'), (2272, 2279, 'skill'), (12852, 12859, 'skill'), (14697, 14704, 'skill'), (1995, 1998, 'skill'), (2581, 2584, 'skill'), (5718, 5721, 'skill'), (5766, 5769, 'skill'), (9271, 9274, 'skill'), (9312, 9315, 'skill'), (12823, 12826, 'skill'), (12804, 12821, 'skill'), (5766, 5772, 'skill'), (5781, 5793, 'skill'), (9321, 9333, 'skill'), (9271, 9278, 'skill'), (5718, 5734, 'skill'), (12852, 12862, 'skill'), (14697, 14707, 'skill'), (2126, 2131, 'skill'), (12771, 12776, 'skill'), (12878, 12883, 'skill'), (1918, 1922, 'skill'), (12743, 12751, 'skill'), (12864, 12883, 'skill'), (2101, 2114, 'skill'), (3447, 3450, 'skill'), (1749, 1752, 'skill'), (1875, 1878, 'skill'), (8715, 8720, 'skill'), (1983, 1993, 'skill'), (2589, 2599, 'skill'), (5670, 5680, 'skill'), (5795, 5817, 'skill'), (14656, 14667, 'skill'), (2391, 2415, 'skill'), (376, 383, 'skill'), (418, 425, 'skill'), (708, 715, 'skill'), (1021, 1028, 'skill'), (1129, 1136, 'skill'), (1219, 1226, 'skill'), (1553, 1560, 'skill'), (2134, 2141, 'skill'), (2164, 2171, 'skill'), (2471, 2478, 'skill'), (2566, 2573, 'skill'), (5903, 5910, 'skill'), (6124, 6131, 'skill'), (6880, 6887, 'skill'), (8538, 8545, 'skill'), (8651, 8658, 'skill'), (9345, 9352, 'skill'), (9465, 9472, 'skill'), (9554, 9561, 'skill'), (9614, 9621, 'skill'), (9837, 9844, 'skill'), (10885, 10892, 'skill'), (10915, 10922, 'skill'), (12512, 12519, 'skill'), (12575, 12582, 'skill'), (12778, 12785, 'skill'), (13019, 13026, 'skill'), (13091, 13098, 'skill'), (13208, 13215, 'skill'), (13510, 13517, 'skill'), (13745, 13752, 'skill'), (13999, 14006, 'skill'), (14021, 14028, 'skill'), (14340, 14347, 'skill'), (14615, 14622, 'skill'), (9922, 9933, 'skill'), (2335, 2339, 'skill'), (2779, 2783, 'skill'), (2943, 2947, 'skill'), (15147, 15151, 'skill'), (1959, 1970, 'skill'), (2391, 2402, 'skill'), (1758, 1763, 'skill'), (8747, 8752, 'skill'), (8857, 8862, 'skill'), (10803, 10808, 'skill'), (1770, 1779, 'skill'), (2848, 2857, 'skill'), (6682, 6691, 'skill'), (12702, 12711, 'skill'), (370, 375, 'skill'), (503, 508, 'skill'), (1547, 1552, 'skill'), (1781, 1786, 'skill'), (2303, 2308, 'skill'), (2675, 2680, 'skill'), (2788, 2793, 'skill'), (2861, 2866, 'skill'), (2895, 2900, 'skill'), (2936, 2941, 'skill'), (6656, 6661, 'skill'), (6747, 6752, 'skill'), (7274, 7279, 'skill'), (7344, 7349, 'skill'), (7541, 7546, 'skill'), (8225, 8230, 'skill'), (8303, 8308, 'skill'), (9871, 9876, 'skill'), (9922, 9927, 'skill'), (10001, 10006, 'skill'), (10136, 10141, 'skill'), (12681, 12686, 'skill'), (1950, 1970, 'skill'), (2198, 2201, 'skill'), (9357, 9360, 'skill'), (2203, 2218, 'skill'), (8904, 8919, 'skill'), (2032, 2034, 'skill'), (5732, 5734, 'skill'), (12841, 12843, 'skill'), (8303, 8320, 'skill'), (13434, 13440, 'skill'), (14647, 14653, 'skill'), (13315, 13323, 'skill'), (5781, 5784, 'skill'), (9321, 9324, 'skill'), (201, 211, 'skill'), (5826, 5836, 'skill'), (7970, 7978, 'skill'), (15085, 15093, 'skill'), (9335, 9340, 'skill'), (3773, 3780, 'skill'), (2949, 2955, 'skill'), (6992, 6998, 'skill'), (7415, 7421, 'skill'), (6192, 6198, 'skill'), (2340, 2343, 'skill'), (2041, 2044, 'skill'), (5749, 5752, 'skill'), (10545, 10547, 'skill'), (12999, 13001, 'skill'), (13856, 13858, 'skill'), (14656, 14658, 'skill'), (14991, 14993, 'skill'), (6747, 6758, 'skill'), (8225, 8236, 'skill'), (2223, 2227, 'skill'), (9354, 9360, 'skill'), (743, 750, 'skill'), (8044, 8051, 'skill'), (12520, ...
# 0
# 4
# 36
# 39
# 68
# 115
# 211
# 375
# 383
# 425
# 508
# 715
# 750
# 1028
# 1136
# 1226
# 1552
# 1560
# 1579
# 1635
# 1747
# 1752
# 1757
# 1763
# 1763
# 1779
# 1786
# 1794
# 1809
# 1845
# 1878
# 1922
# 1970
# 1970
# 1976
# 1993
# 1998
# 2030
# 2034
# 2039
# 2044
# 2049
# 2081
# 2087
# 2099
# 2114
# 2114
# 2131
# 2131
# 2141
# 2171
# 2189
# 2196
# 2201
# 2212
# 2218
# 2227
# 2227
# 2237
# 2237
# 2252
# 2252
# 2279
# 2296
# 2308
# 2322
# 2327
# 2339
# 2343
# 2342
# 2369
# 2389
# 2402
# 2415
# 2478
# 2520
# 2558
# 2573
# 2584
# 2599
# 2680
# 2783
# 2793
# 2857
# 2866
# 2872
# 2872
# 2900
# 2941
# 2947
# 2955
# 2967
# 2977
# 2982
# 3132
# 3450
# 3551
# 3780
# 3913
# 3939
# 4031
# 4036
# 4128
# 4957
# 5295
# 5453
# 5680
# 5692
# 5693
# 5696
# 5711
# 5716
# 5721
# 5734
# 5734
# 5738
# 5742
# 5747
# 5752
# 5764
# 5764
# 5769
# 5772
# 5779
# 5784
# 5793
# 5799
# 5817
# 5836
# 5895
# 5910
# 5925
# 5938
# 5955
# 6045
# 6131
# 6198
# 6661
# 6691
# 6752
# 6758
# 6758
# 6887
# 6998
# 7013
# 7021
# 7279
# 7349
# 7414
# 7421
# 7546
# 7978
# 8002
# 8051
# 8159
# 8230
# 8236
# 8236
# 8308
# 8320
# 8427
# 8545
# 8639
# 8658
# 8673
# 8676
# 8675
# 8691
# 8720
# 8746
# 8752
# 8752
# 8856
# 8862
# 8862
# 8907
# 8919
# 9209
# 9216
# 9240
# 9245
# 9258
# 9259
# 9262
# 9274
# 9278
# 9278
# 9286
# 9294
# 9309
# 9315
# 9319
# 9324
# 9333
# 9340
# 9352
# 9352
# 9360
# 9360
# 9365
# 9381
# 9381
# 9472
# 9504
# 9561
# 9579
# 9600
# 9621
# 9670
# 9803
# 9844
# 9876
# 9927
# 9933
# 9933
# 10006
# 10042
# 10141
# 10223
# 10413
# 10547
# 10802
# 10808
# 10808
# 10892
# 10922
# 11075
# 11334
# 11475
# 11499
# 11655
# 11775
# 11870
# 12421
# 12519
# 12527
# 12582
# 12678
# 12700
# 12686
# 12700
# 12711
# 12751
# 12762
# 12769
# 12769
# 12776
# 12785
# 12802
# 12821
# 12821
# 12826
# 12830
# 12835
# 12839
# 12843
# 12850
# 12859
# 12862
# 12862
# 12875
# 12883
# 12883
# 13001
# 13026
# 13034
# 13043
# 13098
# 13155
# 13215
# 13323
# 13364
# 13378
# 13440
# 13517
# 13567
# 13579
# 13676
# 13752
# 13797
# 13813
# 13822
# 13858
# 13936
# 14006
# 14028
# 14063
# 14082
# 14213
# 14270
# 14293
# 14347
# 14532
# 14540
# 14622
# 14653
# 14658
# 14667
# 14673
# 14681
# 14695
# 14704
# 14707
# 14707
# 14713
# 14721
# 14724
# 14724
# 14732
# 14736
# 14744
# 14752
# 14758
# 14770
# 14993
# 15093
# [(7545, 7558, 'skill'), (8922, 8923, 'skill'), (10031, 10032, 'skill'), (12203, 12204, 'skill'), (12261, 12262, 'skill'), (1902, 1908, 'skill'), (3229, 3235, 'skill'), (9472, 9478, 'skill'), (10165, 10171, 'skill'), (11052, 11058, 'skill'), (11308, 11314, 'skill'), (11572, 11578, 'skill'), (12218, 12224, 'skill'), (13472, 13478, 'skill'), (14113, 14119, 'skill'), (14739, 14745, 'skill'), (256, 260, 'skill'), (2865, 2869, 'skill'), (5996, 6000, 'skill'), (9948, 9952, 'skill'), (976, 983, 'skill'), (3538, 3545, 'skill'), (6946, 6953, 'skill'), (7243, 7250, 'skill'), (6099, 6102, 'skill'), (6093, 6097, 'skill'), (12155, 12159, 'skill'), (1361, 1372, 'skill'), (7294, 7300, 'skill'), (5426, 5436, 'skill'), (8582, 8592, 'skill'), (1810, 1823, 'skill'), (3375, 3388, 'skill'), (14583, 14596, 'skill'), (7100, 7107, 'skill'), (3568, 3573, 'skill'), (6886, 6891, 'skill'), (7344, 7349, 'skill'), (12211, 12216, 'skill'), (13504, 13509, 'skill'), (14623, 14628, 'skill'), (14772, 14777, 'skill'), (2918, 2921, 'skill'), (6010, 6013, 'skill'), (7903, 7906, 'skill'), (9954, 9957, 'skill'), (10770, 10773, 'skill'), (10908, 10911, 'skill'), (12050, 12053, 'skill'), (12166, 12169, 'skill'), (12821, 12824, 'skill'), (12893, 12896, 'skill'), (13430, 13433, 'skill'), (13775, 13778, 'skill'), (14697, 14700, 'skill'), (6528, 6551, 'skill'), (87, 91, 'skill'), (247, 251, 'skill'), (582, 586, 'skill'), (2148, 2152, 'skill'), (2859, 2863, 'skill'), (2898, 2902, 'skill'), (3760, 3764, 'skill'), (4249, 4253, 'skill'), (4320, 4324, 'skill'), (5990, 5994, 'skill'), (6050, 6054, 'skill'), (7730, 7734, 'skill'), (8287, 8291, 'skill'), (8757, 8761, 'skill'), (9942, 9946, 'skill'), (10131, 10135, 'skill'), (10360, 10364, 'skill'), (11350, 11354, 'skill'), (12044, 12048, 'skill'), (12453, 12457, 'skill'), (12652, 12656, 'skill'), (12942, 12946, 'skill'), (13414, 13418, 'skill'), (13704, 13708, 'skill'), (14246, 14250, 'skill'), (14681, 14685, 'skill'), (7365, 7398, 'skill'), (598, 601, 'skill'), (2993, 2996, 'skill'), (4939, 4942, 'skill'), (6088, 6091, 'skill'), (10094, 10097, 'skill'), (12138, 12141, 'skill'), (47, 48, 'skill'), (58, 59, 'skill'), (4563, 4564, 'skill'), (4572, 4573, 'skill'), (7088, 7089, 'skill'), (7090, 7091, 'skill'), (7105, 7106, 'skill'), (7306, 7307, 'skill'), (7319, 7320, 'skill'), (7361, 7362, 'skill'), (7396, 7397, 'skill'), (8921, 8922, 'skill'), (10030, 10031, 'skill'), (12063, 12064, 'skill'), (12065, 12066, 'skill'), (12188, 12189, 'skill'), (12202, 12203, 'skill'), (12207, 12208, 'skill'), (12241, 12242, 'skill'), (12260, 12261, 'skill'), (12273, 12274, 'skill'), (2975, 2982, 'skill'), (3090, 3097, 'skill'), (7282, 7289, 'skill'), (6152, 6155, 'skill'), (11412, 11415, 'skill'), (12245, 12248, 'skill'), (2940, 2950, 'skill'), (3078, 3088, 'skill'), (4540, 4550, 'skill'), (7945, 7955, 'skill'), (9985, 9995, 'skill'), (10913, 10923, 'skill'), (12104, 12114, 'skill'), (12840, 12850, 'skill'), (13447, 13457, 'skill'), (14714, 14724, 'skill'), (3526, 3531, 'skill'), (6346, 6351, 'skill'), (6936, 6941, 'skill'), (7236, 7241, 'skill'), (10124, 10129, 'skill'), (564, 568, 'skill'), (2987, 2991, 'skill'), (3124, 3128, 'skill'), (4227, 4231, 'skill'), (7252, 7256, 'skill'), (9974, 9978, 'skill'), (10735, 10739, 'skill'), (10925, 10929, 'skill'), (12826, 12830, 'skill'), (13441, 13445, 'skill'), (13780, 13784, 'skill'), (14255, 14259, 'skill'), (14708, 14712, 'skill'), (4568, 4575, 'skill'), (7302, 7309, 'skill'), (3563, 3566, 'skill'), (6371, 6374, 'skill'), (7513, 7516, 'skill'), (13491, 13494, 'skill'), (14325, 14328, 'skill'), (14758, 14761, 'skill'), (7451, 7459, 'skill'), (2061, 2068, 'skill'), (13124, 13129, 'skill'), (2070, 2075, 'skill'), (3341, 3346, 'skill'), (3348, 3355, 'skill'), (1851, 1860, 'skill'), (4325, 4332, 'skill'), (1651, 1657, 'skill'), (1664, 1670, 'skill'), (3019, 3025, 'skill'), (3931, 3937, 'skill'), (4059, 4065, 'skill'), (4669, 4675, 'skill'), (5224, 5230, 'skill'), (5331, 5337, 'skill'), (5358, 5364, 'skill'), (5 ...
# 0
# 11
# 19
# 48
# 52
# 59
# 62
# 91
# 121
# 193
# 200
# 251
# 260
# 342
# 407
# 502
# 509
# 516
# 522
# 568
# 575
# 580
# 586
# 593
# 601
# 618
# 661
# 756
# 770
# 793
# 804
# 839
# 846
# 859
# 956
# 983
# 1064
# 1119
# 1150
# 1181
# 1275
# 1284
# 1323
# 1328
# 1340
# 1348
# 1354
# 1367
# 1372
# 1372
# 1382
# 1420
# 1411
# 1420
# 1425
# 1482
# 1644
# 1657
# 1662
# 1662
# 1670
# 1690
# 1726
# 1733
# 1775
# 1816
# 1823
# 1823
# 1839
# 1832
# 1839
# 1846
# 1854
# 1860
# 1908
# 1916
# 1916
# 1927
# 1927
# 1932
# 1959
# 1959
# 2011
# 2068
# 2075
# 2152
# 2257
# 2707
# 2713
# 2713
# 2863
# 2869
# 2874
# 2882
# 2882
# 2902
# 2906
# 2906
# 2916
# 2921
# 2927
# 2933
# 2938
# 2950
# 2956
# 2962
# 2973
# 2982
# 2985
# 2985
# 2991
# 2996
# 3001
# 3007
# 3025
# 3042
# 3047
# 3057
# 3063
# 3088
# 3097
# 3100
# 3100
# 3110
# 3116
# 3122
# 3128
# 3133
# 3144
# 3149
# 3166
# 3176
# 3181
# 3197
# 3203
# 3235
# 3239
# 3243
# 3243
# 3248
# 3255
# 3255
# 3262
# 3280
# 3305
# 3310
# 3315
# 3339
# 3346
# 3355
# 3381
# 3388
# 3388
# 3398
# 3405
# 3411
# 3420
# 3426
# 3435
# 3441
# 3452
# 3474
# 3479
# 3490
# 3531
# 3536
# 3545
# 3552
# 3561
# 3566
# 3573
# 3579
# 3644
# 3764
# 3767
# 3875
# 3902
# 3914
# 3921
# 3937
# 3947
# 3953
# 3980
# 3997
# 4001
# 4065
# 4074
# 4093
# 4127
# 4131
# 4153
# 4185
# 4231
# 4236
# 4247
# 4253
# 4260
# 4270
# 4296
# 4324
# 4332
# 4337
# 4344
# 4355
# 4435
# 4443
# 4450
# 4455
# 4463
# 4477
# 4550
# 4558
# 4564
# 4566
# 4572
# 4575
# 4573
# 4575
# 4588
# 4591
# 4591
# 4606
# 4631
# 4638
# 4675
# 4679
# 4679
# 4701
# 4733
# 4797
# 4816
# 4866
# 4932
# 4937
# 4937
# 4942
# 4949
# 5009
# 5156
# 5197
# 5230
# 5235
# 5235
# 5251
# 5272
# 5282
# 5308
# 5313
# 5337
# 5364
# 5411
# 5432
# 5436
# 5436
# 5519
# 5528
# 5528
# 5548
# 5548
# 5632
# 5632
# 5650
# 5759
# 5803
# 5811
# 5906
# 5913
# 5994
# 5994
# 6000
# 6008
# 6013
# 6019
# 6027
# 6037
# 6048
# 6054
# 6060
# 6065
# 6074
# 6080
# 6085
# 6091
# 6097
# 6102
# 6110
# 6132
# 6155
# 6204
# 6262
# 6351
# 6362
# 6374
# 6470
# 6478
# 6478
# 6508
# 6515
# 6533
# 6539
# 6551
# 6539
# 6662
# 6678
# 6727
# 6732
# 6732
# 6815
# 6832
# 6841
# 6853
# 6891
# 6941
# 6953
# 7031
# 7033
# 7041
# 7046
# 7046
# 7054
# 7062
# 7069
# 7074
# 7092
# 7086
# 7089
# 7091
# 7098
# 7103
# 7107
# 7143
# 7106
# 7138
# 7143
# 7148
# 7153
# 7163
# 7180
# 7191
# 7200
# 7215
# 7215
# 7222
# 7229
# 7234
# 7241
# 7234
# 7241
# 7250
# 7256
# 7261
# 7272
# 7280
# 7289
# 7292
# 7292
# 7300
# 7300
# 7306
# 7309
# 7307
# 7309
# 7319
# 7322
# 7320
# 7322
# 7342
# 7342
# 7349
# 7363
# 7359
# 7361
# 7363
# 7362
# 7370
# 7398
# 7375
# 7394
# 7398
# 7397
# 7404
# 7409
# 7441
# 7441
# 7449
# 7449
# 7459
# 7466
# 7472
# 7511
# 7494
# 7511
# 7516
# 7536
# 7543
# 7536
# 7543
# 7558
# 7561
# 7558
# 7561
# 7561
# 7566
# 7734
# 7847
# 7854
# 7906
# 7955
# 8002
# 8012
# 8027
# 8111
# 8165
# 8169
# 8169
# 8195
# 8223
# 8249
# 8253
# 8253
# 8291
# 8297
# 8358
# 8373
# 8383
# 8389
# 8399
# 8526
# 8588
# 8592
# 8592
# 8644
# 8649
# 8710
# 8714
# 8714
# 8756
# 8761
# 8779
# 8831
# 8919
# 8921
# 8923
# 8922
# 8923
# 9040
# 9049
# 9060
# 9071
# 9076
# 9155
# 9193
# 9184
# 9193
# 9198
# 9221
# 9238
# 9243
# 9262
# 9273
# 9278
# 9278
# 9299
# 9438
# 9465
# 9465
# 9478
# 9487
# 9494
# 9544
# 9563
# 9563
# 9563
# 9615
# 9646
# 9820
# 9896
# 9946
# 9946
# 9952
# 9957
# 9965
# 9957
# 9965
# 9965
# 9971
# 9978
# 9983
# 9995
# 10003
# 10009
# 10017
# 10028
# 10030
# 10032
# 10031
# 10032
# 10037
# 10046
# 10061
# 10066
# 10071
# 10078
# 10087
# 10087
# 10092
# 10097
# 10104
# 10111
# 10111
# 10116
# 10122
# 10129
# 10135
# 10141
# 10146
# 10153
# 10159
# 10171
# 10171
# 10176
# 10188
# 10192
# 10188
# 10192
# 10192
# 10198
# 10364
# 10435
# 10585
# 10618
# 10716
# 10739
# 10741
# 10749
# 10760
# 10765
# 10773
# 10805
# 10844
# 10849
# 10854
# 10911
# 10923
# 10929
# 10938
# 10996
# 11058
# 11061
# 11061
# 11090
# 11107
# 11150
# 11184
# 11219
# 11254
# 11285
# 11314
# 11323
# 11354
# 11415
# 11529
# 11544
# 11578
# 11596
# 11647
# 11756
# 12048
# 12053
# 12061
# 12065
# 12067
# 12064
# 12066
# 12072
# 12078
# 12084
# 12097
# 12088
# 12097
# 12102
# 12114
# 12119
# 12126
# 12131
# 12136
# 12141
# 12147
# 12153
# 12153
# 12159
# 12164
# 12169
# 12175
# 12186
# 12190
# 12190
# 12189
# 12195
# 12200
# 12204
# 12203
# 12204
# 12209
# 12208
# 12216
# 12224
# 12227
# 12227
# 12232
# 12239
# 12243
# 12242
# 12248
# 12253
# 12258
# 12260
# 12262
# 12261
# 12262
# 12271
# 12275
# 12274
# 12281
# 12457
# 12512
# 12564
# 12584
# 12584
# 12656
# 12656
# 12686
# 12720
# 12776
# 12824
# 12830
# 12835
# 12850
# 12868
# 12896
# 12946
# 13045
# 13053
# 13129
# 13147
# 13161
# 13179
# 13255
# 13267
# 13363
# 13367
# 13367
# 13418
# 13428
# 13433
# 13439
# 13445
# 13457
# 13464
# 13470
# 13478
# 13481
# 13489
# 13494
# 13503
# 13509
# 13513
# 13708
# 13778
# 13784
# 13792
# 13814
# 13828
# 14013
# 14021
# 14040
# 14106
# 14119
# 14135
# 14144
# 14207
# 14207
# 14250
# 14259
# 14299
# 14328
# 14388
# 14400
# 14488
# 14496
# 14496
# 14520
# 14574
# 14589
# 14596
# 14596
# 14618
# 14618
# 14628
# 14666
# 14685
# 14695
# 14700
# 14706
# 14712
# 14724
# 14731
# 14737
# 14745
# 14748
# 14756
# 14761
# 14770

# %%
vocab = set()
tags = set()
def build_vocab():
    with open('train_resume.bie') as fp:
        for line in fp.readlines():
            words = line.split()
            if len(words)==2:
                word = words[0]
                tag = words[1]
                vocab.add(word)
                tags.add(tag)

# %%
build_vocab()

# %%
len(vocab)
# Out:
# 9271

# %%
len(tags)
# Out:
# 13

# %%
with open('vocab.txt','w') as fp:
    for word in vocab:
        fp.writelines(word+'\n')

# %%
with open('tags.txt','w') as fp:
    for tag in tags:
        fp.writelines(tag+'\n')
